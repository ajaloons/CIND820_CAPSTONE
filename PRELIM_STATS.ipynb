# %%
print("prelim stats")
# Out:
# prelim stats

# %%
#import libraries

import csv
import pandas as pd
import numpy as np

# %%
#import and read csv file
#display first 10 rows

import pandas as pd
crime_data1 = pd.read_csv(r"C:\Users\radon\Documents\CIND820/crimedata.csv")

crime_data1.head(10)
# Out:
#              communityname state countyCode communityCode  fold  population  \
# 0  BerkeleyHeightstownship    NJ         39          5320     1       11980
# 1           Marpletownship    PA         45         47616     1       23123
# 2               Tigardcity    OR          ?             ?     1       29344
# 3         Gloversvillecity    NY         35         29443     1       16656
# 4              Bemidjicity    MN          7          5068     1       11245
# 5          Springfieldcity    MO          ?             ?     1      140494
# 6              Norwoodtown    MA         21         50250     1       28700
# 7             Andersoncity    IN          ?             ?     1       59459
# 8                Fargocity    ND         17         25700     1       74111
# 9                 Wacocity    TX          ?             ?     1      103590
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  burglaries  \
# 0           3.10          1.37         91.78          6.50  ...          14
# 1           2.82          0.80         95.57          3.44  ...          57
# 2           2.43          0.74         94.33          3.43  ...         274
# 3           2.40          1.70         97.35          0.50  ...         225
# 4           2.76          0.53         89.16          1.17  ...          91
# 5           2.45          2.51         95.65          0.90  ...        2094
# 6           2.60          1.60         96.57          1.47  ...         110
# 7           2.45         14.20         84.87          0.40  ...         608
# 8           2.46          0.35         97.11          1.25  ...         425
# 9           2.62         23.14         67.60          0.92  ...        2397
#
#    burglPerPop  larcenies  larcPerPop  autoTheft  autoTheftPerPop  arsons  \
# 0       114.85        138     1132.08         16           131.26       2
# 1       242.37        376     1598.78         26           110.55       1
# 2       758.14       1797     4972.19        136            376.3      22
# 3      1301.78        716     4142.56         47           271.93       ?
# 4       728.93       1060     8490.87         91           728.93       5
# 5      1386.46       7690     5091.64        454            300.6     134
# 6       372.09        288      974.19        144            487.1      17
# 7        997.6       2250     3691.79        125            205.1       9
# 8       532.66       3149     3946.71        206           258.18       8
# 9      2221.81       6121     5673.63       1070            991.8      18
#
#    arsonsPerPop  ViolentCrimesPerPop  nonViolPerPop
# 0         16.41                41.02        1394.59
# 1          4.25               127.56        1955.95
# 2         60.87               218.59        6167.51
# 3             ?               306.64              ?
# 4         40.05                    ?        9988.79
# 5         88.72               442.95        6867.42
# 6          57.5               226.63        1890.88
# 7         14.77               439.73        4909.26
# 8         10.03               115.31        4747.58
# 9         16.68              1544.24        8903.93
#
# [10 rows x 147 columns]

# %%
#display data types of all columns

datatypes = crime_data1.dtypes
print(datatypes)
# Out:
# communityname          object
# state                  object
# countyCode             object
# communityCode          object
# fold                    int64
#                         ...
# autoTheftPerPop        object
# arsons                 object
# arsonsPerPop           object
# ViolentCrimesPerPop    object
# nonViolPerPop          object
# Length: 147, dtype: object

# %%
#replace all missing values with NaN

import pandas as pd
crime_data = pd.read_csv('crimedata.csv', na_values=['?'])
crime_data.head(10)
# Out:
#              communityname state  countyCode  communityCode  fold  population  \
# 0  BerkeleyHeightstownship    NJ        39.0         5320.0     1       11980
# 1           Marpletownship    PA        45.0        47616.0     1       23123
# 2               Tigardcity    OR         NaN            NaN     1       29344
# 3         Gloversvillecity    NY        35.0        29443.0     1       16656
# 4              Bemidjicity    MN         7.0         5068.0     1       11245
# 5          Springfieldcity    MO         NaN            NaN     1      140494
# 6              Norwoodtown    MA        21.0        50250.0     1       28700
# 7             Andersoncity    IN         NaN            NaN     1       59459
# 8                Fargocity    ND        17.0        25700.0     1       74111
# 9                 Wacocity    TX         NaN            NaN     1      103590
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  burglaries  \
# 0           3.10          1.37         91.78          6.50  ...        14.0
# 1           2.82          0.80         95.57          3.44  ...        57.0
# 2           2.43          0.74         94.33          3.43  ...       274.0
# 3           2.40          1.70         97.35          0.50  ...       225.0
# 4           2.76          0.53         89.16          1.17  ...        91.0
# 5           2.45          2.51         95.65          0.90  ...      2094.0
# 6           2.60          1.60         96.57          1.47  ...       110.0
# 7           2.45         14.20         84.87          0.40  ...       608.0
# 8           2.46          0.35         97.11          1.25  ...       425.0
# 9           2.62         23.14         67.60          0.92  ...      2397.0
#
#    burglPerPop  larcenies  larcPerPop  autoTheft  autoTheftPerPop  arsons  \
# 0       114.85      138.0     1132.08       16.0           131.26     2.0
# 1       242.37      376.0     1598.78       26.0           110.55     1.0
# 2       758.14     1797.0     4972.19      136.0           376.30    22.0
# 3      1301.78      716.0     4142.56       47.0           271.93     NaN
# 4       728.93     1060.0     8490.87       91.0           728.93     5.0
# 5      1386.46     7690.0     5091.64      454.0           300.60   134.0
# 6       372.09      288.0      974.19      144.0           487.10    17.0
# 7       997.60     2250.0     3691.79      125.0           205.10     9.0
# 8       532.66     3149.0     3946.71      206.0           258.18     8.0
# 9      2221.81     6121.0     5673.63     1070.0           991.80    18.0
#
#    arsonsPerPop  ViolentCrimesPerPop  nonViolPerPop
# 0         16.41                41.02        1394.59
# 1          4.25               127.56        1955.95
# 2         60.87               218.59        6167.51
# 3           NaN               306.64            NaN
# 4         40.05                  NaN        9988.79
# 5         88.72               442.95        6867.42
# 6         57.50               226.63        1890.88
# 7         14.77               439.73        4909.26
# 8         10.03               115.31        4747.58
# 9         16.68              1544.24        8903.93
#
# [10 rows x 147 columns]

# %%
#check number of rows
len(crime_data)
# Out:
# 2215

# %%
#check datatypes again

datatypes2 = crime_data.dtypes
print(datatypes2)
# Out:
# communityname           object
# state                   object
# countyCode             float64
# communityCode          float64
# fold                     int64
#                         ...
# autoTheftPerPop        float64
# arsons                 float64
# arsonsPerPop           float64
# ViolentCrimesPerPop    float64
# nonViolPerPop          float64
# Length: 147, dtype: object

# %%
#display the sum of all NaN in each column

crime_data.isnull().sum()
# Out:
# communityname             0
# state                     0
# countyCode             1221
# communityCode          1224
# fold                      0
#                        ...
# autoTheftPerPop           3
# arsons                   91
# arsonsPerPop             91
# ViolentCrimesPerPop     221
# nonViolPerPop            97
# Length: 147, dtype: int64

# %%
#seperate all columns with missing values

null_cols = crime_data[crime_data.columns[crime_data.isna().any()]]
null_cols
# Out:
#       countyCode  communityCode  OtherPerCap  LemasSwornFT  LemasSwFTPerPop  \
# 0           39.0         5320.0       5115.0           NaN              NaN
# 1           45.0        47616.0       5250.0           NaN              NaN
# 2            NaN            NaN       5954.0           NaN              NaN
# 3           35.0        29443.0       2451.0           NaN              NaN
# 4            7.0         5068.0       3000.0           NaN              NaN
# ...          ...            ...          ...           ...              ...
# 2210         NaN            NaN       6470.0           NaN              NaN
# 2211         NaN            NaN      11471.0           NaN              NaN
# 2212         NaN            NaN       8532.0           NaN              NaN
# 2213         NaN            NaN       4436.0           NaN              NaN
# 2214         NaN            NaN       7540.0           NaN              NaN
#
#       LemasSwFTFieldOps  LemasSwFTFieldPerPop  LemasTotalReq  \
# 0                   NaN                   NaN            NaN
# 1                   NaN                   NaN            NaN
# 2                   NaN                   NaN            NaN
# 3                   NaN                   NaN            NaN
# 4                   NaN                   NaN            NaN
# ...                 ...                   ...            ...
# 2210                NaN                   NaN            NaN
# 2211                NaN                   NaN            NaN
# 2212                NaN                   NaN            NaN
# 2213                NaN                   NaN            NaN
# 2214                NaN                   NaN            NaN
#
#       LemasTotReqPerPop  PolicReqPerOffic  ...  burglaries  burglPerPop  \
# 0                   NaN               NaN  ...        14.0       114.85
# 1                   NaN               NaN  ...        57.0       242.37
# 2                   NaN               NaN  ...       274.0       758.14
# 3                   NaN               NaN  ...       225.0      1301.78
# 4                   NaN               NaN  ...        91.0       728.93
# ...                 ...               ...  ...         ...          ...
# 2210                NaN               NaN  ...      1376.0      2268.72
# 2211                NaN               NaN  ...       104.0       860.43
# 2212                NaN               NaN  ...       628.0      1709.26
# 2213                NaN               NaN  ...       192.0      1508.01
# 2214                NaN               NaN  ...       791.0      2614.53
#
#       larcenies  larcPerPop  autoTheft  autoTheftPerPop  arsons  arsonsPerPop  \
# 0         138.0     1132.08       16.0           131.26     2.0         16.41
# 1         376.0     1598.78       26.0           110.55     1.0          4.25
# 2        1797.0     4972.19      136.0           376.30    22.0         60.87
# 3         716.0     4142.56       47.0           271.93     NaN           NaN
# 4        1060.0     8490.87       91.0           728.93     5.0         40.05
# ...         ...         ...        ...              ...     ...           ...
# 2210     2563.0     4225.82      489.0           806.25    34.0         56.06
# 2211      574.0     4748.90       24.0           198.56     2.0         16.55
# 2212      895.0     2435.97      179.0           487.19     8.0         21.77
# 2213      474.0     3722.90       13.0           102.10     1.0          7.85
# 2214     1458.0     4819.20      405.0          1338.67    20.0         66.11
#
#       ViolentCrimesPerPop  nonViolPerPop
# 0                   41.02        1394.59
# 1                  127.56        1955.95
# 2                  218.59        6167.51
# 3                  306.64            NaN
# 4                     NaN        9988.79
# ...                   ...            ...
# 2210               545.75        7356.84
# 2211               124.10        5824.44
# 2212               353.83        4654.20
# 2213               691.17        5340.87
# 2214               918.89        8838.50
#
# [2215 rows x 41 columns]

# %%
#display sums of missing values of only columns that contain missing values

null_list= null_cols.columns.values
null_cols.isnull().sum()
# Out:
# countyCode              1221
# communityCode           1224
# OtherPerCap                1
# LemasSwornFT            1872
# LemasSwFTPerPop         1872
# LemasSwFTFieldOps       1872
# LemasSwFTFieldPerPop    1872
# LemasTotalReq           1872
# LemasTotReqPerPop       1872
# PolicReqPerOffic        1872
# PolicPerPop             1872
# RacialMatchCommPol      1872
# PctPolicWhite           1872
# PctPolicBlack           1872
# PctPolicHisp            1872
# PctPolicAsian           1872
# PctPolicMinor           1872
# OfficAssgnDrugUnits     1872
# NumKindsDrugsSeiz       1872
# PolicAveOTWorked        1872
# PolicCars               1872
# PolicOperBudg           1872
# LemasPctPolicOnPatr     1872
# LemasGangUnitDeploy     1872
# PolicBudgPerPop         1872
# rapes                    208
# rapesPerPop              208
# robberies                  1
# robbbPerPop                1
# assaults                  13
# assaultPerPop             13
# burglaries                 3
# burglPerPop                3
# larcenies                  3
# larcPerPop                 3
# autoTheft                  3
# autoTheftPerPop            3
# arsons                    91
# arsonsPerPop              91
# ViolentCrimesPerPop      221
# nonViolPerPop             97
# dtype: int64

# %%
#change settings to display all columns
pd.set_option('display.max_columns', None)

#get summary statistics of all columns
crime_data.describe()
# Out:
#        countyCode  communityCode         fold    population  householdsize  \
# count  994.000000     991.000000  2215.000000  2.215000e+03    2215.000000
# mean    65.587525   45209.251261     5.494357  5.311798e+04       2.707327
# std    117.831399   25425.861573     2.872924  2.046203e+05       0.334120
# min      1.000000      70.000000     1.000000  1.000500e+04       1.600000
# 25%     11.000000   22887.000000     3.000000  1.436600e+04       2.500000
# 50%     27.000000   46925.000000     5.000000  2.279200e+04       2.660000
# 75%     80.500000   65805.000000     8.000000  4.302400e+04       2.850000
# max    840.000000   94597.000000    10.000000  7.322564e+06       5.280000
#
#        racepctblack  racePctWhite  racePctAsian   racePctHisp  agePct12t21  \
# count   2215.000000   2215.000000   2215.000000   2215.000000  2215.000000
# mean       9.335102     83.979819      2.670203      7.950176    14.445837
# std       14.247156     16.419080      4.473843     14.589832     4.518623
# min        0.000000      2.680000      0.030000      0.120000     4.580000
# 25%        0.860000     76.320000      0.620000      0.930000    12.250000
# 50%        2.870000     90.350000      1.230000      2.180000    13.620000
# 75%       11.145000     96.225000      2.670000      7.810000    15.360000
# max       96.670000     99.630000     57.460000     95.290000    54.400000
#
#        agePct12t29  agePct16t24   agePct65up     numbUrban     pctUrban  \
# count  2215.000000  2215.000000  2215.000000  2.215000e+03  2215.000000
# mean     27.644840    13.975142    11.836393  4.773472e+04    70.465309
# std       6.181517     5.970747     4.777565  2.056067e+05    44.080275
# min       9.380000     4.640000     1.660000  0.000000e+00     0.000000
# 25%      24.415000    11.320000     8.750000  0.000000e+00     0.000000
# 50%      26.780000    12.540000    11.730000  1.804100e+04   100.000000
# 75%      29.205000    14.345000    14.415000  4.191800e+04   100.000000
# max      70.510000    63.620000    52.770000  7.322564e+06   100.000000
#
#            medIncome     pctWWage  pctWFarmSelf   pctWInvInc   pctWSocSec  \
# count    2215.000000  2215.000000   2215.000000  2215.000000  2215.000000
# mean    33984.696163    78.312758      0.881842    43.750935    26.409418
# std     13424.680011     7.950672      0.689006    12.787925     8.295604
# min      8866.000000    31.680000      0.000000     5.810000     4.810000
# 25%     23817.000000    73.400000      0.460000    34.680000    20.770000
# 50%     31441.000000    78.610000      0.690000    42.880000    26.590000
# 75%     41480.500000    84.030000      1.100000    52.740000    31.715000
# max    123625.000000    96.760000      6.530000    89.040000    76.390000
#
#         pctWPubAsst   pctWRetire      medFamInc     perCapInc   whitePerCap  \
# count   2215.000000  2215.000000    2215.000000   2215.000000   2215.000000
# mean       6.801445    15.969002   39857.055079  15603.524605  16567.698420
# std        4.700335     4.622553   14251.206032   6281.558523   6346.840251
# min        0.180000     3.460000   10447.000000   5237.000000   5472.000000
# 25%        3.270000    12.875000   29538.000000  11602.500000  12610.500000
# 50%        5.610000    15.650000   36678.000000  14101.000000  15073.000000
# 75%        9.105000    18.755000   46999.000000  17795.000000  18609.500000
# max       44.820000    45.510000  139008.000000  63302.000000  68850.000000
#
#          blackPerCap   indianPerCap    AsianPerCap    OtherPerCap  \
# count    2215.000000    2215.000000    2215.000000    2214.000000
# mean    11541.749436   12229.191422   14227.989616    9442.765131
# std      9232.102062   14853.836177    9881.266395    7926.466713
# min         0.000000       0.000000       0.000000       0.000000
# 25%      6742.500000    6345.000000    8285.500000    5528.250000
# 50%      9777.000000    9895.000000   12250.000000    8186.000000
# 75%     14526.000000   14757.500000   17327.500000   11525.500000
# max    212120.000000  480000.000000  106165.000000  137000.000000
#
#          HispPerCap   NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# count   2215.000000  2.215000e+03     2215.000000      2215.000000
# mean   11018.998194  7.590853e+03       11.620537         9.186646
# std     5884.063446  3.936146e+04        8.600352         6.666703
# min        0.000000  7.800000e+01        0.640000         0.200000
# 25%     7274.000000  9.125000e+02        4.510000         4.640000
# 50%     9721.000000  2.142000e+03        9.330000         7.740000
# 75%    13418.000000  4.988000e+03       16.905000        11.835000
# max    54648.000000  1.384994e+06       58.000000        49.890000
#
#        PctNotHSGrad  PctBSorMore  PctUnemployed    PctEmploy  PctEmplManu  \
# count   2215.000000  2215.000000    2215.000000  2215.000000  2215.000000
# mean      22.305120    23.056876       6.045242    62.021612    18.228907
# std       10.989517    12.687213       2.895618     8.312045     8.099281
# min        1.460000     1.630000       1.320000    24.820000     2.050000
# 25%       13.920000    14.095000       4.045000    56.490000    12.215000
# 50%       21.380000    19.650000       5.450000    62.440000    17.300000
# 75%       29.195000    29.055000       7.440000    67.825000    23.400000
# max       73.660000    79.180000      31.230000    84.670000    50.030000
#
#        PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# count      2215.000000   2215.000000       2215.000000     2215.000000
# mean         24.532298     13.819165         28.209201        9.127585
# std           6.659470      6.430264          9.326123        2.802747
# min           8.690000      1.370000          6.480000        2.130000
# 25%          20.075000      9.130000         21.910000        7.110000
# 50%          23.390000     13.150000         26.240000        9.150000
# 75%          27.590000     17.665000         32.815000       11.050000
# max          62.670000     44.270000         64.970000       20.080000
#
#        MalePctNevMarr  FemalePctDiv  TotalPctDiv   PersPerFam   PctFam2Par  \
# count     2215.000000   2215.000000  2215.000000  2215.000000  2215.000000
# mean        30.683517     12.325300    10.812515     3.129698    74.059129
# std          8.127991      3.262613     3.000883     0.240743    10.525952
# min         12.060000      3.350000     2.830000     2.290000    22.970000
# 25%         25.450000      9.860000     8.575000     2.990000    67.900000
# 50%         29.000000     12.520000    10.900000     3.100000    75.030000
# 75%         33.410000     14.745000    12.985000     3.220000    81.900000
# max         76.600000     23.920000    22.230000     4.640000    93.600000
#
#        PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# count  2215.000000       2215.000000  2215.000000          2215.000000
# mean     71.227255         81.865422    75.521788            60.542641
# std      12.045048         12.263736    10.365262             8.008937
# min      18.300000          8.700000    20.200000            24.420000
# 25%      63.990000         74.780000    70.170000            55.430000
# 50%      72.530000         83.990000    76.920000            60.710000
# 75%      80.395000         91.675000    82.765000            65.985000
# max      92.580000        100.000000    97.340000            87.970000
#
#         PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar      NumImmig  \
# count  2215.000000          2215.000000          2215.000000  2.215000e+03
# mean     68.854795          2141.418962             3.115499  6.277274e+03
# std       6.679960         14692.582838             3.127681  5.541965e+04
# min      41.950000             0.000000             0.000000  2.000000e+01
# 25%      64.900000           147.000000             1.070000  4.000000e+02
# 50%      69.230000           352.000000             2.040000  1.024000e+03
# 75%      73.495000          1031.500000             3.910000  3.302000e+03
# max      89.370000        527557.000000            27.350000  2.082931e+06
#
#        PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  \
# count     2215.000000   2215.000000   2215.000000    2215.000000
# mean        13.525693     20.421287     27.544181      34.733928
# std          9.780098     12.410355     14.368813      16.327322
# min          0.000000      0.000000      0.000000       0.000000
# 25%          6.695000     11.255000     17.205000      22.725000
# 50%         12.260000     19.080000     26.720000      34.790000
# 75%         17.950000     27.445000     36.495000      46.185000
# max         64.290000     76.160000     80.810000      88.000000
#
#        PctRecentImmig  PctRecImmig5  PctRecImmig8  PctRecImmig10  \
# count     2215.000000   2215.000000   2215.000000    2215.000000
# mean         1.099124      1.697463      2.307503       2.943761
# std          1.595766      2.461060      3.286648       4.246468
# min          0.000000      0.000000      0.000000       0.000000
# 25%          0.170000      0.280000      0.390000       0.520000
# 50%          0.500000      0.750000      1.040000       1.310000
# 75%          1.310000      2.015000      2.700000       3.455000
# max         13.710000     19.930000     25.340000      32.630000
#
#        PctSpeakEnglOnly  PctNotSpeakEnglWell  PctLargHouseFam  \
# count       2215.000000          2215.000000      2215.000000
# mean          87.074993             2.405792         5.386619
# std           14.076087             4.210368         3.794309
# min            6.150000             0.000000         0.960000
# 25%           84.380000             0.510000         3.390000
# 50%           92.180000             0.920000         4.280000
# 75%           95.455000             2.270000         5.870000
# max           98.980000            38.330000        34.870000
#
#        PctLargHouseOccup  PersPerOccupHous  PersPerOwnOccHous  \
# count        2215.000000       2215.000000        2215.000000
# mean            3.915788          2.615842           2.740483
# std             3.175770          0.315646           0.297421
# min             0.440000          1.580000           1.610000
# 25%             2.370000          2.410000           2.550000
# 50%             3.050000          2.570000           2.710000
# 75%             4.210000          2.770000           2.900000
# max            30.870000          4.520000           4.480000
#
#        PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  PctHousLess3BR  \
# count         2215.000000      2215.000000       2215.000000     2215.000000
# mean             2.367138        66.369454          4.132438       45.405341
# std              0.391806        14.182588          5.599131       13.778347
# min              1.550000        13.930000          0.050000        3.060000
# 25%              2.110000        57.285000          1.290000       37.505000
# 50%              2.290000        65.910000          2.340000       46.390000
# 75%              2.530000        76.580000          4.730000       53.515000
# max              4.730000        97.240000         59.490000       95.340000
#
#           MedNumBR     HousVacant  PctHousOccup  PctHousOwnOcc  \
# count  2215.000000    2215.000000   2215.000000    2215.000000
# mean      2.640632    1748.368849     92.933973      63.368298
# std       0.512686    6503.866478      5.040736      13.970057
# min       1.000000      36.000000     37.470000      16.860000
# 25%       2.000000     304.500000     91.290000      54.820000
# 50%       3.000000     558.000000     94.210000      62.830000
# 75%       3.000000    1228.000000     96.020000      72.645000
# max       4.000000  172768.000000     99.000000      96.490000
#
#        PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# count       2215.000000     2215.000000     2215.000000     2215.000000
# mean           2.778524       34.773887     1962.623476        4.289824
# std            3.592396       13.911468       11.166555        4.088175
# min            0.000000        3.120000     1939.000000        0.000000
# 25%            0.720000       24.480000     1956.000000        0.905000
# 50%            1.660000       34.100000     1964.000000        2.850000
# 75%            3.430000       43.970000     1971.000000        6.805000
# max           39.890000       82.130000     1987.000000       23.880000
#
#        PctWOFullPlumb  OwnOccLowQuart   OwnOccMedVal  OwnOccHiQuart  \
# count     2215.000000     2215.000000    2215.000000    2215.000000
# mean         0.425273    88695.802257  113097.523251  145318.257788
# std          0.426188    66670.781534   81906.362277   99030.913816
# min          0.000000    14999.000000   19500.000000   28200.000000
# 25%          0.160000    41500.000000   56200.000000   74300.000000
# 50%          0.320000    65500.000000   82800.000000  106700.000000
# 75%          0.555000   121500.000000  150600.000000  188000.000000
# max          5.330000   500001.000000  500001.000000  500001.000000
#
#         OwnOccQrange     RentLowQ   RentMedian    RentHighQ   RentQrange  \
# count    2215.000000  2215.000000  2215.000000  2215.000000  2215.000000
# mean    56622.455530   329.966591   428.537246   527.252822   197.286230
# std     39106.498041   144.138461   170.706644   199.290780    85.205688
# min         0.000000    99.000000   120.000000   182.000000     0.000000
# 25%     32200.000000   213.500000   289.500000   366.000000   139.000000
# 50%     43400.000000   307.000000   397.000000   486.000000   171.000000
# 75%     65450.000000   421.000000   544.000000   659.500000   232.500000
# max    331000.000000  1001.000000  1001.000000  1001.000000   803.000000
#
#            MedRent  MedRentPctHousInc  MedOwnCostPctInc  \
# count  2215.000000        2215.000000       2215.000000
# mean    501.466366          26.298104         20.990158
# std     169.271735           2.979297          2.987622
# min     192.000000          14.900000         14.000000
# 25%     364.000000          24.300000         18.700000
# 50%     467.000000          26.100000         21.000000
# 75%     615.000000          28.000000         23.100000
# max    1001.000000          35.100000         32.700000
#
#        MedOwnCostPctIncNoMtg  NumInShelters     NumStreet  PctForeignBorn  \
# count            2215.000000    2215.000000   2215.000000     2215.000000
# mean               13.010203      66.953499     17.823476        7.340302
# std                 1.419679     564.253149    245.452553        8.418476
# min                10.100000       0.000000      0.000000        0.180000
# 25%                12.000000       0.000000      0.000000        2.060000
# 50%                12.800000       0.000000      0.000000        4.310000
# 75%                13.700000      22.000000      1.000000        9.250000
# max                23.400000   23383.000000  10447.000000       60.400000
#
#        PctBornSameState  PctSameHouse85  PctSameCity85  PctSameState85  \
# count       2215.000000     2215.000000    2215.000000     2215.000000
# mean          61.539630       51.538596      77.411079       88.111865
# std           16.750061       10.517926      10.878186        7.287836
# min            6.750000       11.830000      27.950000       32.830000
# 25%           50.110000       44.995000      72.060000       85.200000
# 50%           64.490000       52.170000      79.490000       90.030000
# 75%           74.855000       58.740000      85.135000       93.010000
# max           93.140000       78.560000      96.590000       99.900000
#
#        LemasSwornFT  LemasSwFTPerPop  LemasSwFTFieldOps  LemasSwFTFieldPerPop  \
# count    343.000000       343.000000         343.000000            343.000000
# mean     499.198251       246.490962         432.559767            210.844781
# std     1681.472251       273.799162        1493.708385            235.478815
# min       65.000000        29.400000          14.000000             19.210000
# 25%      131.000000       149.115000         114.000000            132.245000
# 50%      173.000000       196.010000         152.000000            170.270000
# 75%      314.000000       260.650000         285.500000            226.815000
# max    25655.000000      3437.230000       22496.000000           3290.620000
#
#        LemasTotalReq  LemasTotReqPerPop  PolicReqPerOffic  PolicPerPop  \
# count   3.430000e+02       3.430000e+02        343.000000   343.000000
# mean    2.524050e+05       1.206517e+05        523.658309   246.493586
# std     6.894498e+05       1.482113e+05        307.839007   273.798409
# min     2.100000e+03       2.704800e+03         20.800000    29.400000
# 25%     4.986450e+04       6.484505e+04        343.350000   149.150000
# 50%     9.000000e+04       9.103460e+04        443.200000   196.000000
# 75%     1.719235e+05       1.303246e+05        637.250000   260.650000
# max     8.328470e+06       1.926282e+06       2162.500000  3437.200000
#
#        RacialMatchCommPol  PctPolicWhite  PctPolicBlack  PctPolicHisp  \
# count          343.000000     343.000000     343.000000    343.000000
# mean            85.499679      82.515831       9.263294      5.459767
# std             10.941312      15.332612      11.021424     10.604533
# min             42.150000       1.600000       0.000000      0.000000
# 25%             79.435000      76.230000       2.020000      0.415000
# 50%             87.930000      86.180000       5.000000      2.040000
# 75%             93.645000      93.340000      14.065000      6.215000
# max            100.000000     100.000000      67.310000     98.400000
#
#        PctPolicAsian  PctPolicMinor  OfficAssgnDrugUnits  NumKindsDrugsSeiz  \
# count     343.000000     343.000000           343.000000         343.000000
# mean        0.681283      15.242245            26.288630           8.816327
# std         1.706344      14.826756           100.821921           2.836391
# min         0.000000       0.000000             0.000000           1.000000
# 25%         0.000000       4.950000             6.000000           7.000000
# 50%         0.000000      11.370000            12.000000           9.000000
# 75%         0.650000      19.740000            23.000000          10.500000
# max        18.570000      98.400000          1773.000000          15.000000
#
#        PolicAveOTWorked     LandArea       PopDens  PctUsePubTrans  \
# count        343.000000  2215.000000   2215.000000     2215.000000
# mean         119.114286    27.419955   2783.835034        3.041124
# std           92.495186   109.822600   2828.993341        4.912917
# min            0.000000     0.900000     10.000000        0.000000
# 25%           55.100000     7.300000   1181.900000        0.360000
# 50%           98.700000    13.700000   2027.300000        1.220000
# 75%          153.550000    26.100000   3321.700000        3.365000
# max          634.700000  3569.800000  44229.900000       54.330000
#
#          PolicCars  PolicOperBudg  LemasPctPolicOnPatr  LemasGangUnitDeploy  \
# count   343.000000   3.430000e+02           343.000000           343.000000
# mean    185.478134   3.217602e+07            87.130933             4.285714
# std     318.542834   1.104566e+08            10.349612             4.064538
# min      20.000000   2.380215e+06            10.850000             0.000000
# 25%      54.000000   7.275060e+06            84.295000             0.000000
# 50%      86.000000   1.116411e+07            89.580000             5.000000
# 75%     189.500000   2.014754e+07            93.200000            10.000000
# max    3187.000000   1.617293e+09            99.940000            10.000000
#
#        LemasPctOfficDrugUn  PolicBudgPerPop      murders   murdPerPop  \
# count          2215.000000     3.430000e+02  2215.000000  2215.000000
# mean              0.980163     1.535779e+05     7.764786     5.859296
# std               2.877128     2.030409e+05    58.166468     9.156829
# min               0.000000     1.526040e+04     0.000000     0.000000
# 25%               0.000000     8.809435e+04     0.000000     0.000000
# 50%               0.000000     1.145820e+05     1.000000     2.170000
# 75%               0.000000     1.556557e+05     3.000000     8.365000
# max              48.440000     2.422367e+06  1946.000000    91.090000
#
#              rapes  rapesPerPop     robberies  robbbPerPop      assaults  \
# count  2007.000000   2007.00000   2214.000000  2214.000000   2202.000000
# mean     28.046338     36.25848    237.952123   162.612597    326.528156
# std     105.616135     34.23975   2250.720788   234.486624   1987.947941
# min       0.000000      0.00000      0.000000     0.000000      0.000000
# 25%       2.000000     11.53500      5.000000    27.647500     18.000000
# 50%       7.000000     26.92000     19.000000    74.800000     56.000000
# 75%      19.000000     51.47000     70.000000   187.155000    180.000000
# max    2818.000000    401.35000  86001.000000  2264.130000  62778.000000
#
#        assaultPerPop    burglaries   burglPerPop      larcenies    larcPerPop  \
# count    2202.000000   2212.000000   2212.000000    2212.000000   2212.000000
# mean      378.004605    761.236890   1033.430203    2137.629295   3372.979150
# std       438.238599   3111.702756    763.354442    7600.573464   1901.316145
# min         0.000000      2.000000     16.920000      10.000000     77.860000
# 25%        94.187500     95.000000    511.690000     392.000000   2040.080000
# 50%       226.525000    205.000000    822.715000     747.000000   3079.510000
# 75%       504.387500    508.000000   1350.232500    1675.000000   4335.410000
# max      4932.500000  99207.000000  11881.020000  235132.000000  25910.550000
#
#            autoTheft  autoTheftPerPop       arsons  arsonsPerPop  \
# count    2212.000000      2212.000000  2124.000000   2124.000000
# mean      516.692586       473.965628    30.907721     32.153682
# std      3258.164244       504.666026   180.125248     39.240900
# min         1.000000         6.550000     0.000000      0.000000
# 25%        30.000000       156.952500     1.000000      7.670000
# 50%        75.000000       302.355000     5.000000     21.080000
# 75%       232.500000       589.775000    16.000000     42.852500
# max    112464.000000      4968.590000  5119.000000    436.370000
#
#        ViolentCrimesPerPop  nonViolPerPop
# count          1994.000000    2118.000000
# mean            589.078922    4908.241804
# std             614.784518    2739.708901
# min               0.000000     116.790000
# 25%             161.700000    2918.070000
# 50%             374.060000    4425.450000
# 75%             794.400000    6229.280000
# max            4877.060000   27119.760000

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Columns: 147 entries, communityname to nonViolPerPop
# dtypes: float64(116), int64(29), object(2)
# memory usage: 2.5+ MB

# %%
#find the mean of each column by state
mean_data = crime_data.groupby("state").mean()
mean_data.head()
# Out:
# C:\Users\radon\AppData\Local\Temp\ipykernel_3604\3113613801.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_data = crime_data.groupby("state").mean()
#        countyCode  communityCode      fold     population  householdsize  \
# state
# AK            NaN            NaN  7.333333   94644.000000       2.756667
# AL            NaN            NaN  6.000000   39231.186047       2.611860
# AR            NaN            NaN  5.440000   32674.520000       2.652800
# AZ            NaN            NaN  5.700000  125811.650000       2.778500
# CA           76.0        93325.0  5.591398   79654.179211       2.926129
#
#        racepctblack  racePctWhite  racePctAsian   racePctHisp  agePct12t21  \
# state
# AK         6.826667     77.906667      4.136667      4.086667    13.986667
# AL        27.044651     71.799535      0.750000      0.665116    16.117209
# AR        19.470000     78.883600      0.835600      0.979200    16.207600
# AZ         2.610500     84.655500      1.574500     22.434500    14.850000
# CA         5.312222     71.973799      9.480896     24.799427    13.974158
#
#        agePct12t29  agePct16t24   agePct65up      numbUrban   pctUrban  \
# state
# AK       29.586667    13.966667     4.303333   73915.000000  32.656667
# AL       28.540233    15.227209    12.415581   34182.069767  64.992558
# AR       29.028800    15.354400    12.666400   20450.480000  40.000000
# AZ       27.722500    13.808500    11.690500  114430.000000  54.660000
# CA       28.252581    13.678136     9.780287   76204.000000  85.266989
#
#           medIncome   pctWWage  pctWFarmSelf  pctWInvInc  pctWSocSec  \
# state
# AK     41301.000000  89.586667      1.083333   74.923333   10.960000
# AL     26034.860465  75.144419      0.855814   33.825349   28.445814
# AR     22025.560000  73.618400      1.258000   32.592800   29.241200
# AZ     32264.500000  77.323000      0.952000   38.545500   25.294000
# CA     39655.982079  80.120394      0.827849   40.754624   21.825520
#
#         pctWPubAsst  pctWRetire     medFamInc     perCapInc   whitePerCap  \
# state
# AK         6.843333   13.766667  46051.333333  18068.333333  19928.333333
# AL         8.100930   15.898837  33033.232558  13065.651163  14933.186047
# AR         8.465200   14.075200  27477.320000  11245.760000  12798.640000
# AZ         6.444000   16.827500  37024.700000  15380.050000  16208.950000
# CA         8.877240   14.881900  44720.125448  17465.885305  18957.817204
#
#         blackPerCap  indianPerCap   AsianPerCap   OtherPerCap    HispPerCap  \
# state
# AK     12596.666667  10115.333333  12005.333333  12153.000000  11534.666667
# AL      7357.930233  12009.325581  12114.069767   6510.232558  10418.418605
# AR      7215.760000   8606.000000  10218.360000   9461.120000   7651.240000
# AZ     14505.700000  10459.250000  12970.100000   7450.900000   9127.850000
# CA     13960.465950  14410.684588  15125.035842  10407.967742  11528.028674
#
#         NumUnderPov  PctPopUnderPov  PctLess9thGrade  PctNotHSGrad  \
# state
# AK      6681.666667        7.683333         3.480000     11.176667
# AL      7405.232558       17.863256        11.406977     27.426279
# AR      5535.720000       18.780800        12.641600     29.064400
# AZ     17101.050000       15.036500         9.917500     21.542500
# CA      9958.157706       10.789140        10.443297     22.795986
#
#        PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  PctEmplProfServ  \
# state
# AK       25.300000       6.610000  72.913333     3.343333        24.726667
# AL       23.013023       6.635581  57.156047    19.573953        26.390698
# AR       16.950800       6.596000  58.104000    19.264000        24.798400
# AZ       21.650500       7.012000  59.707500    12.751500        22.172500
# CA       23.964158       6.350860  63.222581    16.795376        22.322186
#
#        PctOccupManu  PctOccupMgmtProf  MalePctDivorce  MalePctNevMarr  \
# state
# AK         8.743333         31.840000       12.896667       31.660000
# AL        16.170233         28.505814        9.366047       29.517907
# AR        17.750800         23.689200       10.165600       27.406400
# AZ        11.422000         27.247000        9.869000       28.504500
# CA        12.847097         28.926344        9.677957       32.928100
#
#        FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  PctKids2Par  \
# state
# AK        16.116667    14.440000    3.196667   74.700000    73.003333
# AL        13.030698    11.367674    3.075116   69.230698    64.306744
# AR        13.674000    12.065200    3.058000   69.728400    65.208800
# AZ        13.229000    11.610000    3.175000   74.329500    70.758500
# CA        14.002688    11.870323    3.304301   74.187312    70.442652
#
#        PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  PctWorkMom  \
# state
# AK            81.053333    78.000000            63.173333   72.633333
# AL            76.904186    70.583023            63.534884   69.728837
# AR            76.107600    71.822800            64.511200   71.568800
# AZ            82.037000    76.480000            58.645500   66.129000
# CA            83.169928    75.711541            56.891039   64.844875
#
#        NumKidsBornNeverMar  PctKidsBornNeverMar      NumImmig  PctImmigRecent  \
# state
# AK             1865.333333             3.133333   5397.333333       12.216667
# AL             1965.325581             4.789070    687.255814       18.807209
# AR             1191.000000             3.995200    547.760000       19.377200
# AZ             3050.750000             2.618000  10154.800000       14.418000
# CA             2630.627240             3.391505  19501.440860       15.708638
#
#        PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# state
# AK        20.800000     32.660000      40.870000        0.653333
# AL        28.404186     33.491860      42.968140        0.294884
# AR        25.513200     37.754800      43.952000        0.251600
# AZ        23.323000     30.726000      37.103500        1.459000
# CA        24.847025     34.214588      43.798459        3.295878
#
#        PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# state
# AK         1.106667      1.730000       2.153333         90.686667
# AL         0.434419      0.531163       0.648837         96.534651
# AR         0.360400      0.540400       0.656000         96.800800
# AZ         2.286000      2.925500       3.545000         78.144000
# CA         5.196667      7.149247       9.209498         70.336953
#
#        PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  \
# state
# AK                1.236667         5.390000           3.676667
# AL                0.424186         4.433023           3.093023
# AR                0.546000         4.402000           3.130800
# AZ                4.111000         7.035500           5.244500
# CA                7.405412         9.233799           7.007849
#
#        PersPerOccupHous  PersPerOwnOccHous  PersPerRentOccHous  \
# state
# AK             2.653333           2.783333            2.503333
# AL             2.520000           2.629767            2.335349
# AR             2.522800           2.589200            2.421600
# AZ             2.706500           2.793000            2.571500
# CA             2.851111           2.885735            2.788244
#
#        PctPersOwnOccup  PctPersDenseHous  PctHousLess3BR  MedNumBR  \
# state
# AK           49.940000          5.586667        53.32000  2.333333
# AL           65.245581          2.924186        41.71000  2.860465
# AR           62.018800          3.427600        45.65840  2.880000
# AZ           65.994500          6.886500        49.96900  2.550000
# CA           59.075663         11.628315        51.37086  2.448029
#
#         HousVacant  PctHousOccup  PctHousOwnOcc  PctVacantBoarded  \
# state
# AK     4613.000000     89.246667      47.370000          5.843333
# AL     1366.395349     92.252093      62.581628          2.883953
# AR     1280.440000     91.835600      60.400000          3.585200
# AZ     7948.600000     84.915000      64.188000          1.902000
# CA     1725.663082     94.359534      58.164552          1.918746
#
#        PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  PctWOFullPlumb  \
# state
# AK          39.796667     1973.666667        5.483333        1.216667
# AL          37.815349     1966.976744        6.644186        0.640930
# AR          37.975200     1968.120000        9.751200        0.581600
# AZ          27.634500     1975.900000        6.852500        0.329000
# CA          20.730000     1967.225806        2.712939        0.429749
#
#        OwnOccLowQuart   OwnOccMedVal  OwnOccHiQuart  OwnOccQrange    RentLowQ  \
# state
# AK       78433.333333  102866.666667  132533.333333  54100.000000  407.000000
# AL       46648.837209   63955.813953   89079.069767  42430.232558  170.465116
# AR       37220.000000   51488.000000   71760.000000  34540.000000  176.960000
# AZ       72980.000000   95985.000000  128820.050000  55840.050000  311.200000
# CA      175336.935484  219367.068100  269462.820789  94125.885305  490.584229
#
#        RentMedian   RentHighQ  RentQrange     MedRent  MedRentPctHousInc  \
# state
# AK     527.333333  673.666667  266.666667  580.000000          24.900000
# AL     246.697674  325.372093  154.906977  336.627907          25.218605
# AR     245.360000  313.600000  136.640000  339.800000          26.880000
# AZ     405.650000  499.500000  188.300000  476.700000          28.175000
# CA     607.885305  732.716846  242.132616  665.078853          28.691756
#
#        MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# state
# AK            21.500000              11.300000     130.000000  25.000000
# AL            18.051163              12.688372      32.093023   7.883721
# AR            19.428000              13.452000      15.200000   1.440000
# AZ            22.770000              12.635000     125.350000  30.350000
# CA            24.844086              11.708602     100.139785  49.885305
#
#        PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# state
# AK           5.243333         28.786667       35.826667      64.576667
# AL           1.483488         71.264186       51.849767      78.885349
# AR           1.369200         63.527600       48.319200      75.919200
# AZ           9.245500         29.936000       39.551000      68.547000
# CA          19.687204         48.018280       44.247742      74.198208
#
#        PctSameState85  LemasSwornFT  LemasSwFTPerPop  LemasSwFTFieldOps  \
# state
# AK          72.073333    266.000000       104.930000         252.000000
# AL          87.704419    293.833333       184.121667         252.500000
# AR          85.816000    111.666667       147.090000          88.000000
# AZ          74.233000    611.833333       139.425000         575.000000
# CA          87.774265    458.061224       157.247959         386.244898
#
#        LemasSwFTFieldPerPop  LemasTotalReq  LemasTotReqPerPop  \
# state
# AK                99.410000  107811.000000       42529.000000
# AL               155.971667  141162.166667       87517.881667
# AR               117.630000   51710.000000       73882.933333
# AZ               130.758333  512103.833333      116322.850000
# CA               134.820204  311710.979592      103479.571020
#
#        PolicReqPerOffic  PolicPerPop  RacialMatchCommPol  PctPolicWhite  \
# state
# AK           405.300000   104.900000           89.390000      89.470000
# AL           431.033333   184.150000           81.233333      75.255000
# AR           447.833333   147.100000           76.176667      85.573333
# AZ           849.000000   139.416667           96.275000      89.226667
# CA           694.083673   157.248980           82.908571      74.932041
#
#        PctPolicBlack  PctPolicHisp  PctPolicAsian  PctPolicMinor  \
# state
# AK          4.140000      1.880000       2.630000       8.650000
# AL         23.325000      0.425000       0.720000      24.471667
# AR         14.156667      0.000000       0.270000      14.426667
# AZ          1.680000      8.370000       0.415000      10.463333
# CA          7.714694     10.421837       3.077551      20.878571
#
#        OfficAssgnDrugUnits  NumKindsDrugsSeiz  PolicAveOTWorked     LandArea  \
# state
# AK               16.000000          11.000000          0.000000  1492.733333
# AL               14.333333           8.500000        164.500000    37.248837
# AR                9.333333           7.333333         42.933333    26.832000
# AZ               21.500000          11.000000        161.200000    78.850000
# CA               24.877551           9.591837        181.189796    33.169534
#
#            PopDens  PctUsePubTrans   PolicCars  PolicOperBudg  \
# state
# AK      363.033333        2.916667  301.000000   2.941312e+07
# AL     1143.448837        0.523023  167.166667   1.356148e+07
# AR     1241.868000        0.415200   70.666667   5.969266e+06
# AZ     1375.160000        1.103000  366.833333   4.265164e+07
# CA     4693.495699        3.265878  173.734694   3.961899e+07
#
#        LemasPctPolicOnPatr  LemasGangUnitDeploy  LemasPctOfficDrugUn  \
# state
# AK               94.740000            10.000000             2.006667
# AL               81.938333             5.833333             0.753953
# AR               78.543333             3.333333             0.979600
# AZ               93.966667             6.666667             1.469500
# CA               87.499388             6.020408             1.124695
#
#        PolicBudgPerPop    murders  murdPerPop      rapes  rapesPerPop  \
# state
# AK       116028.100000   9.666667    8.870000  83.000000    66.080000
# AL        82293.251667   7.581395   11.342093  24.325581    42.825349
# AR        67721.166667   5.680000   10.735600  25.440000    52.083600
# AZ        98273.283333  12.400000    4.613500  58.600000    30.195000
# CA       154858.814490  11.727599    8.134588  32.491039    32.646882
#
#         robberies  robbbPerPop    assaults  assaultPerPop   burglaries  \
# state
# AK     217.000000   156.103333  523.666667     345.516667   753.000000
# AL     135.720930   199.333721  374.093023     777.197674   708.418605
# AR     102.600000   195.645600  290.560000     460.085200   652.680000
# AZ     292.500000   119.256000  810.000000     397.030000  2281.450000
# CA     406.215054   273.137276  535.151079     496.704964  1098.870968
#
#        burglPerPop    larcenies   larcPerPop    autoTheft  autoTheftPerPop  \
# state
# AK      639.463333  4325.666667  3813.090000   562.333333       485.286667
# AL     1273.725814  1869.255814  3730.038605   260.720930       399.103953
# AR     1450.826400  1856.600000  4575.336800   222.760000       450.897200
# AZ     1510.476500  6869.450000  4325.365000  1501.850000       661.164500
# CA     1248.996595  2694.913978  3022.680896   965.017921       819.774265
#
#           arsons  arsonsPerPop  ViolentCrimesPerPop  nonViolPerPop
# state
# AK     38.000000     23.833333           576.576667    4961.673333
# AL     30.812500     35.178750          1030.699070    6025.023750
# AR     15.760000     32.514800           718.550400    6509.575600
# AZ     45.100000     35.179000           551.094500    6532.186000
# CA     55.698925     47.988530           810.469388    5139.440251

# %%
#find the mean of crime per pop columns by state
state_crimes =crime_data.groupby("state")["murdPerPop", "rapesPerPop", "robbbPerPop", "assaultPerPop", "burglPerPop", "larcPerPop", "autoTheftPerPop", "arsonsPerPop"].mean()
state_crimes.head(5)
# Out:
# C:\Users\radon\AppData\Local\Temp\ipykernel_3604\230491955.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   state_crimes =crime_data.groupby("state")["murdPerPop", "rapesPerPop", "robbbPerPop", "assaultPerPop", "burglPerPop", "larcPerPop", "autoTheftPerPop", "arsonsPerPop"].mean()
#        murdPerPop  rapesPerPop  robbbPerPop  assaultPerPop  burglPerPop  \
# state
# AK       8.870000    66.080000   156.103333     345.516667   639.463333
# AL      11.342093    42.825349   199.333721     777.197674  1273.725814
# AR      10.735600    52.083600   195.645600     460.085200  1450.826400
# AZ       4.613500    30.195000   119.256000     397.030000  1510.476500
# CA       8.134588    32.646882   273.137276     496.704964  1248.996595
#
#         larcPerPop  autoTheftPerPop  arsonsPerPop
# state
# AK     3813.090000       485.286667     23.833333
# AL     3730.038605       399.103953     35.178750
# AR     4575.336800       450.897200     32.514800
# AZ     4325.365000       661.164500     35.179000
# CA     3022.680896       819.774265     47.988530

# %%
#find the states with min and max mean values for crimes
state_crimes["murdPerPop"].sort_values()
state_crimes["rapesPerPop"].sort_values()
state_crimes["robbbPerPop"].sort_values()
state_crimes["assaultPerPop"].sort_values()
state_crimes["burglPerPop"].sort_values()
state_crimes["larcPerPop"].sort_values()
state_crimes["autoTheftPerPop"].sort_values()
state_crimes["arsonsPerPop"].sort_values()

# %%
#find representation of each state in dataset, how many rows does each state have?
crime_data.groupby(['state'])['state'].count()
# Out:
# state
# AK      3
# AL     43
# AR     25
# AZ     20
# CA    279
# CO     25
# CT     71
# DC      1
# DE      1
# FL     90
# GA     37
# IA     20
# ID      7
# IL     40
# IN     48
# KS      1
# KY     26
# LA     22
# MA    123
# MD     12
# ME     17
# MI    108
# MN     66
# MO     42
# MS     20
# NC     46
# ND      8
# NH     21
# NJ    211
# NM     10
# NV      5
# NY     46
# OH    111
# OK     36
# OR     31
# PA    101
# RI     26
# SC     28
# SD      9
# TN     35
# TX    162
# UT     24
# VA     33
# VT      4
# WA     40
# WI     60
# WV     14
# WY      7
# Name: state, dtype: int64

# %% [markdown]
# ALL CODE BELOW FOR NEXT PHASE OF PROJECT, STILL IN DEVELOPMENT

# %%
az = crime_data.loc[crime_data['state'] == "CA"]
az.boxplot(column="murdPerPop")

#dc = crime_data.loc[crime_data['state']== "DC"]

# %% [markdown]
# Previously, we have discovered a number of missing values in the dataset. The number of values missing in each column varies. At this point, there are missing number values which are significant and cannot be used in the analysis. These columns will have to be dropped. I have decided on a NaN threshold of 50% (0.5), so any columns which are missing 50% of its values or more will be dropped from the dataset.

# %%
#after deciding on a NaN ratio threshold, drop the columns which exceed the threshold (50%)

crimedata_reduced= crime_data.drop(['countyCode', 'communityCode', 'fold', 'LemasSwornFT', 'LemasSwFTPerPop', 'LemasSwFTFieldOps', 'LemasSwFTFieldPerPop', 'LemasTotalReq', 'LemasTotReqPerPop', 'PolicReqPerOffic', 'PolicPerPop', 'RacialMatchCommPol', 'PctPolicWhite', 'PctPolicBlack', 'PctPolicHisp', 'PctPolicAsian', 'PctPolicMinor', 'OfficAssgnDrugUnits', 'NumKindsDrugsSeiz', 'PolicAveOTWorked', 'PolicCars', 'PolicOperBudg', 'LemasPctPolicOnPatr', 'LemasGangUnitDeploy', 'PolicBudgPerPop'], axis=1)
crimedata_reduced
# Out:
#                 communityname state  population  householdsize  racepctblack  \
# 0     BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1              Marpletownship    PA       23123           2.82          0.80
# 2                  Tigardcity    OR       29344           2.43          0.74
# 3            Gloversvillecity    NY       16656           2.40          1.70
# 4                 Bemidjicity    MN       11245           2.76          0.53
# ...                       ...   ...         ...            ...           ...
# 2210               Mercedcity    CA       56216           3.07          6.87
# 2211            Pinevillecity    LA       12251           2.68         21.18
# 2212              Yucaipacity    CA       32824           2.46          0.52
# 2213             Beevillecity    TX       13547           2.89          3.37
# 2214       WestSacramentocity    CA       28898           2.61          2.39
#
#       racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0            91.78          6.50          1.88        12.47        21.44
# 1            95.57          3.44          0.85        11.01        21.30
# 2            94.33          3.43          2.35        11.36        25.88
# 3            97.35          0.50          0.70        12.55        25.20
# 4            89.16          1.17          0.52        24.46        40.53
# ...            ...           ...           ...          ...          ...
# 2210         61.68         15.23         29.86        15.46        30.16
# 2211         76.65          1.52          1.29        17.36        31.23
# 2212         92.62          0.98         11.00        11.81        20.96
# 2213         69.91          0.90         62.11        17.16        30.01
# 2214         71.27          9.09         24.43        12.99        25.21
#
#       agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0           10.93        11.33      11980     100.00       75122     89.24
# 1           10.48        17.18      23123     100.00       47917     78.99
# 2           11.01        10.28      29344     100.00       35669     82.00
# 3           12.19        17.57          0       0.00       20580     68.15
# 4           28.69        12.65          0       0.00       17390     69.33
# ...           ...          ...        ...        ...         ...       ...
# 2210        14.34         8.08      56216     100.00       24727     75.05
# 2211        16.97        12.57      12251     100.00       20321     75.06
# 2212         9.53        20.73      32824     100.00       27182     59.79
# 2213        14.73        10.42          0       0.00       19899     71.67
# 2214        11.63        12.12      28664      99.19       23287     68.89
#
#       pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  \
# 0             1.55       70.20       23.62          1.03       18.39
# 1             1.11       64.11       35.50          2.75       22.85
# 2             1.15       55.73       22.25          2.94       14.56
# 3             0.24       38.95       39.48         11.71       18.33
# 4             0.55       42.82       32.16         11.21       14.43
# ...            ...         ...         ...           ...         ...
# 2210          1.12       31.42       21.45         19.98       14.41
# 2211          0.47       33.25       27.63          8.85       18.23
# 2212          0.51       44.72       43.40          9.01       23.56
# 2213          1.70       21.94       26.44         13.05       10.29
# 2214          1.20       27.54       28.62         19.05       17.29
#
#       medFamInc   perCapInc  whitePerCap  blackPerCap  indianPerCap  \
# 0         79584       29711        30233        13600          5725
# 1         55323       20148        20191        18137             0
# 2         42112       16946        17103        16644         21606
# 3         26501       10810        10909         9984          4941
# 4         24018        8483         9009          887          4425
# ...         ...         ...          ...          ...           ...
# 2210      27388       10237        13041         8344          8590
# 2211      25000        9995        11353         5768         10910
# 2212      34973       14131        14416        13630         13197
# 2213      22103        8100         9555         6437          8271
# 2214      27897       11510        13074         8163          9874
#
#       AsianPerCap  OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  \
# 0           27101       5115.0       22838          227            1.96
# 1           20074       5250.0       12222          885            3.98
# 2           15528       5954.0        8405         1389            4.75
# 3            3541       2451.0        4391         2831           17.23
# 4            3352       3000.0        1328         2855           29.99
# ...           ...          ...         ...          ...             ...
# 2210         3399       6470.0        6644        13804           25.06
# 2211         1718      11471.0        4883         2364           20.79
# 2212        17313       8532.0        9398         2460            7.56
# 2213          171       4436.0        5338         4021           30.32
# 2214         6827       7540.0        8275         5287           18.50
#
#       PctLess9thGrade  PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  \
# 0                5.81          9.90        48.18           2.70      64.55
# 1                5.61         13.72        29.89           2.43      61.96
# 2                2.80          9.09        30.13           4.01      69.80
# 3               11.05         33.68        10.81           9.86      54.74
# 4               12.15         23.06        25.28           9.08      52.44
# ...               ...           ...          ...            ...        ...
# 2210            17.12         30.87        15.79           9.99      55.53
# 2211            12.51         27.71        19.28           7.90      54.64
# 2212             7.82         26.14        12.42           5.18      50.54
# 2213            24.37         39.63        12.40          12.12      52.53
# 2214            13.93         33.68         8.86           9.27      53.35
#
#       PctEmplManu  PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  \
# 0           14.65            28.82          5.49             50.73
# 1           12.26            29.28          6.39             37.64
# 2           15.95            21.52          8.79             32.48
# 3           31.22            27.43         26.76             22.71
# 4            6.89            36.54         10.94             27.80
# ...           ...              ...           ...               ...
# 2210        13.47            27.18         16.38             25.02
# 2211         7.81            37.06         10.37             28.73
# 2212         9.34            23.36         13.53             23.54
# 2213         8.22            25.16         10.63             20.87
# 2214         9.44            17.75         19.61             17.44
#
#       MalePctDivorce  MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  \
# 0               3.67           26.38          5.22         4.47        3.22
# 1               4.23           27.99          6.45         5.42        3.11
# 2              10.10           25.78         14.76        12.55        2.95
# 3              10.98           28.15         14.47        12.91        2.98
# 4               7.51           50.66         11.64         9.73        2.98
# ...              ...             ...           ...          ...         ...
# 2210           10.22           31.91         16.28        13.34        3.56
# 2211           10.86           29.51         16.12        13.77        3.12
# 2212            9.89           20.56         12.38        11.23        2.99
# 2213           10.35           29.18         14.36        12.48        3.46
# 2214           15.77           29.72         18.84        17.31        3.20
#
#       PctFam2Par  PctKids2Par  PctYoungKids2Par  PctTeen2Par  \
# 0          91.43        90.17             95.78        95.81
# 1          86.91        85.33             96.82        86.46
# 2          78.54        78.85             92.37        75.72
# 3          64.02        62.36             65.38        67.43
# 4          58.59        55.20             66.51        79.17
# ...          ...          ...               ...          ...
# 2210       67.04        64.81             76.19        72.78
# 2211       68.57        63.66             80.29        73.68
# 2212       76.77        74.20             76.92        82.42
# 2213       67.76        63.45             87.82        74.12
# 2214       62.64        60.23             72.43        66.15
#
#       PctWorkMomYoungKids  PctWorkMom  NumKidsBornNeverMar  \
# 0                   44.56       58.88                   31
# 1                   51.14       62.43                   43
# 2                   66.08       74.19                  164
# 3                   59.59       70.27                  561
# 4                   61.22       68.94                  402
# ...                   ...         ...                  ...
# 2210                47.24       55.38                 1960
# 2211                64.20       66.67                  277
# 2212                55.73       62.62                  434
# 2213                50.57       60.14                  279
# 2214                50.44       57.32                 1152
#
#       PctKidsBornNeverMar  NumImmig  PctImmigRecent  PctImmigRec5  \
# 0                    0.36      1277            8.69         13.00
# 1                    0.24      1920            5.21          8.65
# 2                    0.88      1468           16.42         23.98
# 3                    3.84       339           13.86         13.86
# 4                    4.70       196           46.94         56.12
# ...                   ...       ...             ...           ...
# 2210                 4.49     10623           22.97         35.12
# 2211                 2.98       275            2.91         45.09
# 2212                 1.60      2414            6.63          9.03
# 2213                 2.35       309            4.85          8.09
# 2214                 4.85      4765           31.54         39.50
#
#       PctImmigRec8  PctImmigRec10  PctRecentImmig  PctRecImmig5  PctRecImmig8  \
# 0            20.99          30.93            0.93          1.39          2.24
# 1            13.33          22.50            0.43          0.72          1.11
# 2            32.08          35.63            0.82          1.20          1.61
# 3            15.34          15.34            0.28          0.28          0.31
# 4            67.86          69.90            0.82          0.98          1.18
# ...            ...            ...             ...           ...           ...
# 2210         42.10          60.31            4.34          6.64          7.96
# 2211         65.45          75.64            0.07          1.01          1.47
# 2212         17.15          26.72            0.49          0.66          1.26
# 2213         11.00          20.71            0.11          0.18          0.25
# 2214         46.32          55.97            5.20          6.51          7.64
#
#       PctRecImmig10  PctSpeakEnglOnly  PctNotSpeakEnglWell  PctLargHouseFam  \
# 0              3.30             85.68                 1.37             4.81
# 1              1.87             87.79                 1.81             4.25
# 2              1.78             93.11                 1.14             2.97
# 3              0.31             94.98                 0.56             3.93
# 4              1.22             94.64                 0.39             5.23
# ...             ...               ...                  ...              ...
# 2210          11.40             65.33                11.87            13.49
# 2211           1.70             92.78                 0.86             5.03
# 2212           1.97             88.95                 1.70             5.10
# 2213           0.47             48.92                 6.66             9.83
# 2214           9.23             74.98                 7.76             8.58
#
#       PctLargHouseOccup  PersPerOccupHous  PersPerOwnOccHous  \
# 0                  4.17              2.99               3.00
# 1                  3.34              2.70               2.83
# 2                  2.05              2.42               2.69
# 3                  2.56              2.37               2.51
# 4                  3.11              2.35               2.55
# ...                 ...               ...                ...
# 2210               9.91              3.03               2.83
# 2211               3.37              2.49               2.58
# 2212               3.50              2.44               2.37
# 2213               7.10              2.84               2.93
# 2214               5.70              2.58               2.45
#
#       PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  PctHousLess3BR  \
# 0                   2.84            91.46              0.39           11.06
# 1                   1.96            89.03              1.01           23.60
# 2                   2.06            64.18              2.03           47.46
# 3                   2.20            58.18              1.21           45.66
# 4                   2.12            58.13              2.94           55.64
# ...                  ...              ...               ...             ...
# 2210                3.19            41.69             16.89           57.23
# 2211                2.39            56.06              3.99           54.48
# 2212                2.67            74.61              4.39           61.03
# 2213                2.73            60.11              9.64           50.28
# 2214                2.76            52.72             11.31           61.63
#
#       MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  PctVacantBoarded  \
# 0            3          64         98.37          91.01              3.12
# 1            3         240         97.15          84.88              0.00
# 2            3         544         95.68          57.79              0.92
# 3            3         669         91.19          54.89              2.54
# 4            2         333         92.45          53.57              3.90
# ...        ...         ...           ...            ...               ...
# 2210         2         683         96.40          44.63              1.46
# 2211         2         523         89.72          54.24              4.59
# 2212         2         957         93.30          76.81              0.84
# 2213         2         802         85.39          58.39              5.61
# 2214         2         600         94.85          55.68              3.67
#
#       PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  PctWOFullPlumb  \
# 0              37.50            1959            0.00            0.28
# 1              18.33            1958            0.31            0.14
# 2               7.54            1976            1.55            0.12
# 3              57.85            1939            7.00            0.87
# 4              42.64            1958            7.45            0.82
# ...              ...             ...             ...             ...
# 2210           13.18            1973            4.91            0.55
# 2211           46.08            1966            7.56            0.12
# 2212           29.47            1967            2.51            0.27
# 2213           67.21            1964           15.91            0.87
# 2214           28.67            1960            7.37            1.43
#
#       OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  RentLowQ  \
# 0             215900        262600         326900        111000       685
# 1             136300        164200         199900         63600       467
# 2              74700         90400         112000         37300       370
# 3              36400         49600          66500         30100       195
# 4              30600         43200          59500         28900       202
# ...              ...           ...            ...           ...       ...
# 2210           71200         91100         118900         47700       298
# 2211           33600         52000          72700         39100       176
# 2212           91700        123900         164000         72300       347
# 2213           26000         37800          52100         26100       135
# 2214           68400         87600         114900         46500       272
#
#       RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0           1001       1001         316     1001               23.8
# 1            560        672         205      627               27.6
# 2            428        520         150      484               24.1
# 3            250        309         114      333               28.7
# 4            283        362         160      332               32.2
# ...          ...        ...         ...      ...                ...
# 2210         374        455         157      438               29.8
# 2211         248        297         121      330               23.8
# 2212         451        551         204      514               30.5
# 2213         227        317         182      316               26.2
# 2214         369        449         177      426               30.9
#
#       MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0                 21.1                   14.0             11          0
# 1                 20.7                   12.5              0          0
# 2                 21.7                   11.6             16          0
# 3                 20.6                   14.5              0          0
# 4                 23.2                   12.9              2          0
# ...                ...                    ...            ...        ...
# 2210              22.6                   11.7             64          0
# 2211              17.3                   14.4              0          0
# 2212              23.9                   13.1             44          0
# 2213              23.3                   14.1              0          0
# 2214              21.2                   11.6             10          2
#
#       PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0              10.66             53.72           65.29          78.09
# 1               8.30             77.17           71.27          90.22
# 2               5.00             44.77           36.60          61.26
# 3               2.04             88.71           56.70          90.17
# 4               1.74             73.75           42.22          60.34
# ...              ...               ...             ...            ...
# 2210           18.90             52.67           39.19          74.58
# 2211            2.24             75.16           49.12          78.79
# 2212            7.35             48.66           46.73          75.54
# 2213            2.28             82.26           54.05          79.72
# 2214           16.49             55.29           48.74          66.20
#
#       PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0              89.14       6.5   1845.9            9.63                  0.0
# 1              96.12      10.6   2186.7            3.84                  0.0
# 2              82.85      10.6   2780.9            4.37                  0.0
# 3              96.24       5.2   3217.7            3.31                  0.0
# 4              89.02      11.5    974.2            0.38                  0.0
# ...              ...       ...      ...             ...                  ...
# 2210           85.88      16.7   3365.4            0.59                  0.0
# 2211           92.85       7.3   1682.8            1.15                  0.0
# 2212           92.30      27.5   1195.2            0.12                  0.0
# 2213           94.06       6.3   2142.2            0.00                  0.0
# 2214           89.08      21.7   1331.0            1.39                  0.0
#
#       murders  murdPerPop  rapes  rapesPerPop  robberies  robbbPerPop  \
# 0           0        0.00    0.0         0.00        1.0         8.20
# 1           0        0.00    1.0         4.25        5.0        21.26
# 2           3        8.30    6.0        16.60       56.0       154.95
# 3           0        0.00   10.0        57.86       10.0        57.86
# 4           0        0.00    NaN          NaN        4.0        32.04
# ...       ...         ...    ...          ...        ...          ...
# 2210       10       16.49   30.0        49.46      121.0       199.50
# 2211        0        0.00    4.0        33.09        1.0         8.27
# 2212        5       13.61    5.0        13.61       24.0        65.32
# 2213        0        0.00    2.0        15.71        7.0        54.98
# 2214        5       16.53   19.0        62.80      102.0       337.15
#
#       assaults  assaultPerPop  burglaries  burglPerPop  larcenies  larcPerPop  \
# 0          4.0          32.81        14.0       114.85      138.0     1132.08
# 1         24.0         102.05        57.0       242.37      376.0     1598.78
# 2         14.0          38.74       274.0       758.14     1797.0     4972.19
# 3         33.0         190.93       225.0      1301.78      716.0     4142.56
# 4         14.0         112.14        91.0       728.93     1060.0     8490.87
# ...        ...            ...         ...          ...        ...         ...
# 2210     170.0         280.29      1376.0      2268.72     2563.0     4225.82
# 2211      10.0          82.73       104.0       860.43      574.0     4748.90
# 2212      96.0         261.29       628.0      1709.26      895.0     2435.97
# 2213      79.0         620.48       192.0      1508.01      474.0     3722.90
# 2214     152.0         502.41       791.0      2614.53     1458.0     4819.20
#
#       autoTheft  autoTheftPerPop  arsons  arsonsPerPop  ViolentCrimesPerPop  \
# 0          16.0           131.26     2.0         16.41                41.02
# 1          26.0           110.55     1.0          4.25               127.56
# 2         136.0           376.30    22.0         60.87               218.59
# 3          47.0           271.93     NaN           NaN               306.64
# 4          91.0           728.93     5.0         40.05                  NaN
# ...         ...              ...     ...           ...                  ...
# 2210      489.0           806.25    34.0         56.06               545.75
# 2211       24.0           198.56     2.0         16.55               124.10
# 2212      179.0           487.19     8.0         21.77               353.83
# 2213       13.0           102.10     1.0          7.85               691.17
# 2214      405.0          1338.67    20.0         66.11               918.89
#
#       nonViolPerPop
# 0           1394.59
# 1           1955.95
# 2           6167.51
# 3               NaN
# 4           9988.79
# ...             ...
# 2210        7356.84
# 2211        5824.44
# 2212        4654.20
# 2213        5340.87
# 2214        8838.50
#
# [2215 rows x 122 columns]

# %% [markdown]
# There are still a number of columns that remain with missing values. The number of NaNs, however, were below the threshold of 0.5 so they will be used in the analysis. To deal with these missing values, we will turn to imputation. For the columns with 1-15 total missing values, I have chosen to impute them with the overall mode of the column. Because the distribution of the columns is skewed, I have chosen to impute with the mode value per each individual column.
#
# However, there are still a number of columns with a significant number of missing values, but fall below the threshold. These will have to be dealt with differently. For these values, I have chosen to aggregate the data first, and then choose my imputation method. The nature of the organization of the crimes is by neighbourhood, which are each found in a state. I thought aggregrating by state was the most logical choice, as we may find more geographical, social, and economic similarties overall (but not entirely) within each state and its population. Because there are a different number of neighbourhoods represented for each state, the representation is unbalanced. Because of this, I thought the most appropriate imputation method would be to impute these missing values with the mean by state, per each column.

# %%
#impute missing values
#for columns with very small number of missing values, impute with MODE

crimedata_reduced['robberies'].fillna(crimedata_reduced['robberies'].mode()[0], inplace=True)
crimedata_reduced['robbbPerPop'].fillna(crimedata_reduced['robbbPerPop'].mode()[0], inplace=True)
crimedata_reduced['burglaries'].fillna(crimedata_reduced['burglaries'].mode()[0], inplace=True)
crimedata_reduced['burglPerPop'].fillna(crimedata_reduced['burglPerPop'].mode()[0], inplace=True)
crimedata_reduced['larcenies'].fillna(crimedata_reduced['larcenies'].mode()[0], inplace=True)
crimedata_reduced['larcPerPop'].fillna(crimedata_reduced['larcPerPop'].mode()[0], inplace=True)
crimedata_reduced['autoTheft'].fillna(crimedata_reduced['autoTheft'].mode()[0], inplace=True)
crimedata_reduced['autoTheftPerPop'].fillna(crimedata_reduced['autoTheftPerPop'].mode()[0], inplace=True)
crimedata_reduced['OtherPerCap'].fillna(crimedata_reduced['OtherPerCap'].mode()[0], inplace=True)
crimedata_reduced['assaults'].fillna(crimedata_reduced['assaults'].mode()[0], inplace=True)
crimedata_reduced['assaultPerPop'].fillna(crimedata_reduced['assaultPerPop'].mode()[0], inplace=True)

# %%
#Find out the total counts of how many times each state is represented in the dataset
#With this information, I have chosen to impute by the mean value of the column, aggregated by state

#crimedata_reduced[crimedata_reduced['rapes'].isnull()]
#crimedata_reduced.pivot_table(index = ['state'], aggfunc ='size')

from collections import Counter
print(Counter(crimedata_reduced['state']))
# Out:
# Counter({'CA': 279, 'NJ': 211, 'TX': 162, 'MA': 123, 'OH': 111, 'MI': 108, 'PA': 101, 'FL': 90, 'CT': 71, 'MN': 66, 'WI': 60, 'IN': 48, 'NY': 46, 'NC': 46, 'AL': 43, 'MO': 42, 'WA': 40, 'IL': 40, 'GA': 37, 'OK': 36, 'TN': 35, 'VA': 33, 'OR': 31, 'SC': 28, 'KY': 26, 'RI': 26, 'AR': 25, 'CO': 25, 'UT': 24, 'LA': 22, 'NH': 21, 'MS': 20, 'AZ': 20, 'IA': 20, 'ME': 17, 'WV': 14, 'MD': 12, 'NM': 10, 'SD': 9, 'ND': 8, 'WY': 7, 'ID': 7, 'NV': 5, 'VT': 4, 'AK': 3, 'KS': 1, 'DE': 1, 'DC': 1})

# %% [markdown]
# At this point, I will go through each state, and aggregate them one by one into their own, new data frames. For each seperate state dataframe, I will check for missing values. Rather than checking for the total number, I want the column names of where these missing values are located. I will then confirm the total length/number of rows in the dataset, and then check the total number of missing values in each column to get an idea of how much information is missing in each column per state. If the ratio is not significant, I will then move forward and impute the missing values as discussed previously, and then confirm if there are still any columns left with missing values.
#
# Once confirmed that there are no longer any columns missing values, I will have to put these values back into the main dataset. I have filtered out the main dataset by state, so I will create a new dataframe titled crimedata_new. This new dataframe will include all the data, EXCEPT the data of the particular state I was working with. I will then append the seperate state dataframe to crimedata_new, replacing the old data of the state in which values were missing. Once again, I will confirm that all missing values were imputed as planned, by checking the count of missing values of crimedata_new, indexed by the particular state.

# %% [markdown]
# STATE: CA

# %%
#Separate all rows represented by the state CA, and create a dataframe with them
CA = crimedata_reduced[crimedata_reduced['state']=='CA']
CA_df= pd.DataFrame(CA)

#Check for missing values: return names of each column that carries a missing value
CA_df.columns[CA_df.isna().any()]

#Check the total number of rows represented by the particular state
len(CA_df)

#Check total number of missing values in that column to establish the ratio of missing information that exists here
CA_df['ViolentCrimesPerPop'].isna().sum()

#If the ratio of missing information is not significant, impute the missing values with the mean of that column of its own state
CA_df['ViolentCrimesPerPop'].fillna(CA_df['ViolentCrimesPerPop'].mean(), inplace = True)

#Confirm values were successfully imputed
CA_df.columns[CA_df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
#Create a dataframe where we filter out all rows represented by the particular state
ca_filtered = crimedata_reduced[crimedata_reduced['state'] != 'CA']

#Create a new dataframe which will serve as our main, fully imputed dataframe
#In this new dataframe, take the filtered dataframe and append the imputed state dataframe to it
crimedata_new = pd.concat([ca_filtered, CA_df], ignore_index=True)

#Confirm there are no missing values in the rows of the particular state in the new main dataframe
Counter(crimedata_new[crimedata_new['state'] == "CA"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# I will repeat the previous steps with every single state represented. If no columns are returned with missing values, I will move onto the next state.

# %% [markdown]
# STATE: NJ

# %%
NJ = crimedata_reduced[crimedata_reduced['state']=='NJ']
NJ_df= pd.DataFrame(NJ)
NJ_df.columns[NJ_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: TX

# %%
TX = crimedata_reduced[crimedata_reduced['state']=='TX']
TX_df= pd.DataFrame(TX)
TX_df.columns[TX_df.isna().any()]

len(TX_df)
TX_df['rapes'].isna().sum()
TX_df['rapesPerPop'].isna().sum()
TX_df['arsons'].isna().sum()
TX_df['arsonsPerPop'].isna().sum()
TX_df['ViolentCrimesPerPop'].isna().sum()
TX_df['nonViolPerPop'].isna().sum()

# %%
TX_df['rapes'].fillna(TX_df['rapes'].mean(), inplace = True)
TX_df['rapesPerPop'].fillna(TX_df['rapesPerPop'].mean(), inplace = True)
TX_df['arsons'].fillna(TX_df['arsons'].mean(), inplace = True)
TX_df['arsonsPerPop'].fillna(TX_df['arsonsPerPop'].mean(), inplace = True)
TX_df['ViolentCrimesPerPop'].fillna(TX_df['ViolentCrimesPerPop'].mean(), inplace = True)
TX_df['nonViolPerPop'].fillna(TX_df['nonViolPerPop'].mean(), inplace = True)

TX_df.columns[TX_df.isna().any()]

tx_filtered = crimedata_reduced[crimedata_reduced['state'] != 'TX']
crimedata_new = pd.concat([tx_filtered, TX_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "TX"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: MA

# %%
MA = crimedata_reduced[crimedata_reduced['state']=='MA']
MA_df= pd.DataFrame(MA)
MA_df.columns[MA_df.isna().any()]

len(MA_df)
MA_df['arsons'].isna().sum()
MA_df['arsonsPerPop'].isna().sum()
MA_df['ViolentCrimesPerPop'].isna().sum()
MA_df['nonViolPerPop'].isna().sum()

# %%
MA_df['arsons'].fillna(MA_df['arsons'].mean(), inplace = True)
MA_df['arsonsPerPop'].fillna(MA_df['arsonsPerPop'].mean(), inplace = True)
MA_df['ViolentCrimesPerPop'].fillna(MA_df['ViolentCrimesPerPop'].mean(), inplace = True)
MA_df['nonViolPerPop'].fillna(MA_df['nonViolPerPop'].mean(), inplace = True)

MA_df.columns[MA_df.isna().any()]

ma_filtered = crimedata_reduced[crimedata_reduced['state'] != 'MA']
crimedata_new = pd.concat([ma_filtered, MA_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "MA"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: OH

# %%
OH = crimedata_reduced[crimedata_reduced['state']=='OH']
OH_df= pd.DataFrame(OH)
OH_df.columns[OH_df.isna().any()]

len(OH_df)
OH_df['arsons'].isna().sum()
OH_df['arsonsPerPop'].isna().sum()
OH_df['ViolentCrimesPerPop'].isna().sum()
OH_df['nonViolPerPop'].isna().sum()

# %%
OH_df['arsons'].fillna(OH_df['arsons'].mean(), inplace = True)
OH_df['arsonsPerPop'].fillna(OH_df['arsonsPerPop'].mean(), inplace = True)
OH_df['ViolentCrimesPerPop'].fillna(OH_df['ViolentCrimesPerPop'].mean(), inplace = True)
OH_df['nonViolPerPop'].fillna(OH_df['nonViolPerPop'].mean(), inplace = True)

OH_df.columns[OH_df.isna().any()]

oh_filtered = crimedata_reduced[crimedata_reduced['state'] != 'OH']
crimedata_new = pd.concat([oh_filtered, OH_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "OH"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# ***********************For the state MI, I have run into a problem. Out of the 6 columns which include missing values, 3 of the columns are able to be imputed, as they are not missing a significant amount of values. However the other 3 are missing ALL values in the entire column. This particular state is represented by 108 rows. The columns, rapes, rapesPerPop and ViolentCrimesPerPop are missing all 108 values.

# %% [markdown]
# STATE: MI

# %%
MI = crimedata_reduced[crimedata_reduced['state']=='MI']
MI_df= pd.DataFrame(MI)
MI_df.columns[MI_df.isna().any()]

len(MI_df)

#TOTAL rows for MI was 108
#The three columns beneath are missing ALL 108 values in these columns, there are no values to work with in order to impute the mean
MI_df['ViolentCrimesPerPop'].isna().sum()
MI_df['rapes'].isna().sum()
MI_df['rapesPerPop'].isna().sum()

#The following rows are not missing an insignificant amount of values, they can be imputed as planned
MI_df['arsons'].isna().sum()
MI_df['arsonsPerPop'].isna().sum()
MI_df['nonViolPerPop'].isna().sum()

# %%
#Impute the columns that are appropriate to be imputed by the mean

MI_df['arsons'].fillna(MI_df['arsons'].mean(), inplace = True)
MI_df['arsonsPerPop'].fillna(MI_df['arsonsPerPop'].mean(), inplace = True)
MI_df['nonViolPerPop'].fillna(MI_df['nonViolPerPop'].mean(), inplace = True)

MI_df.columns[MI_df.isna().any()]

mi_filtered = crimedata_reduced[crimedata_reduced['state'] != 'MI']
crimedata_new = pd.concat([mi_filtered, MI_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "MI"].isna().any())
MI_df.columns[MI_df.isna().any()]

#There are still 3 columns that have not been addressed
#These columns must be revisited
# Out:
# Index(['rapes', 'rapesPerPop', 'ViolentCrimesPerPop'], dtype='object')

# %% [markdown]
# STATE: PA

# %%
PA = crimedata_reduced[crimedata_reduced['state']=='PA']
PA_df= pd.DataFrame(PA)
PA_df.columns[PA_df.isna().any()]

len(PA_df)
PA_df['arsons'].isna().sum()
PA_df['arsonsPerPop'].isna().sum()
PA_df['nonViolPerPop'].isna().sum()

# %%
PA_df['arsons'].fillna(PA_df['arsons'].mean(), inplace = True)
PA_df['arsonsPerPop'].fillna(PA_df['arsonsPerPop'].mean(), inplace = True)
PA_df['nonViolPerPop'].fillna(PA_df['nonViolPerPop'].mean(), inplace = True)

PA_df.columns[PA_df.isna().any()]

pa_filtered = crimedata_reduced[crimedata_reduced['state'] != 'PA']
crimedata_new = pd.concat([pa_filtered, PA_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "PA"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: FL

# %%
FL = crimedata_reduced[crimedata_reduced['state']=='FL']
FL_df= pd.DataFrame(FL)
FL_df.columns[FL_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: CT

# %%
CT = crimedata_reduced[crimedata_reduced['state']=='CT']
CT_df= pd.DataFrame(CT)
CT_df.columns[CT_df.isna().any()]

len(CT_df)
CT_df['ViolentCrimesPerPop'].isna().sum()

# %%
CT_df['ViolentCrimesPerPop'].fillna(CT_df['ViolentCrimesPerPop'].mean(), inplace = True)

CT_df.columns[CT_df.isna().any()]

ct_filtered = crimedata_reduced[crimedata_reduced['state'] != 'CT']
crimedata_new = pd.concat([ct_filtered, CT_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "CT"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: MN

# %%
MN = crimedata_reduced[crimedata_reduced['state']=='MN']
MN_df= pd.DataFrame(MN)
MN_df.columns[CA_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: WI

# %%
WI = crimedata_reduced[crimedata_reduced['state']=='WI']
WI_df= pd.DataFrame(WI)
WI_df.columns[WI_df.isna().any()]

len(WI_df)
WI_df['arsons'].isna().sum()
WI_df['arsonsPerPop'].isna().sum()
WI_df['nonViolPerPop'].isna().sum()

# %%
WI_df['arsons'].fillna(WI_df['arsons'].mean(), inplace = True)
WI_df['arsonsPerPop'].fillna(WI_df['arsonsPerPop'].mean(), inplace = True)
WI_df['nonViolPerPop'].fillna(WI_df['nonViolPerPop'].mean(), inplace = True)

WI_df.columns[WI_df.isna().any()]

wi_filtered = crimedata_reduced[crimedata_reduced['state'] != 'WI']
crimedata_new = pd.concat([wi_filtered, WI_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "WI"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: IN

# %%
IN = crimedata_reduced[crimedata_reduced['state']=='IN']
IN_df= pd.DataFrame(IN)
IN_df.columns[IN_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: NY
# *************MISSING VALUES 0.37

# %%
NY = crimedata_reduced[crimedata_reduced['state']=='NY']
NY_df= pd.DataFrame(NY)
NY_df.columns[NY_df.isna().any()]

len(NY_df)
NY_df['arsons'].isna().sum()
NY_df['arsonsPerPop'].isna().sum()
NY_df['nonViolPerPop'].isna().sum()
# Out:
# 17

# %%
NY_df['arsons'].fillna(NY_df['arsons'].mean(), inplace = True)
NY_df['arsonsPerPop'].fillna(NY_df['arsonsPerPop'].mean(), inplace = True)
NY_df['nonViolPerPop'].fillna(NY_df['nonViolPerPop'].mean(), inplace = True)

NY_df.columns[NY_df.isna().any()]

ny_filtered = crimedata_reduced[crimedata_reduced['state'] != 'NY']
crimedata_new = pd.concat([ny_filtered, NY_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "NY"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: NC

# %%
NC = crimedata_reduced[crimedata_reduced['state']=='NC']
NC_df= pd.DataFrame(NC)
NC_df.columns[NC_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: AL
# ************MISSING VALUES 0.63

# %%
AL = crimedata_reduced[crimedata_reduced['state']=='AL']
AL_df= pd.DataFrame(AL)
AL_df.columns[AL_df.isna().any()]

len(AL_df)
AL_df['arsons'].isna().sum()
AL_df['arsonsPerPop'].isna().sum()
AL_df['nonViolPerPop'].isna().sum()

len(AL_df)

# %%
AL_df['arsons'].fillna(AL_df['arsons'].mean(), inplace = True)
AL_df['arsonsPerPop'].fillna(AL_df['arsonsPerPop'].mean(), inplace = True)
AL_df['nonViolPerPop'].fillna(AL_df['nonViolPerPop'].mean(), inplace = True)

AL_df.columns[AL_df.isna().any()]

al_filtered = crimedata_reduced[crimedata_reduced['state'] != 'AL']
crimedata_new = pd.concat([al_filtered, AL_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "AL"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: MO

# %%
MO = crimedata_reduced[crimedata_reduced['state']=='MO']
MO_df= pd.DataFrame(MO)
MO_df.columns[MO_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: WA

# %%
WA = crimedata_reduced[crimedata_reduced['state']=='WA']
WA_df= pd.DataFrame(WA)
WA_df.columns[WA_df.isna().any()]

len(WA_df)
WA_df['arsons'].isna().sum()
WA_df['arsonsPerPop'].isna().sum()
WA_df['nonViolPerPop'].isna().sum()

# %%
WA_df['arsons'].fillna(WA_df['arsons'].mean(), inplace = True)
WA_df['arsonsPerPop'].fillna(WA_df['arsonsPerPop'].mean(), inplace = True)
WA_df['nonViolPerPop'].fillna(WA_df['nonViolPerPop'].mean(), inplace = True)

WA_df.columns[WA_df.isna().any()]

wa_filtered = crimedata_reduced[crimedata_reduced['state'] != 'WA']
crimedata_new = pd.concat([wa_filtered, WA_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "WA"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: IL
# ************MISSING VALUES 1.0: All columns which are missing values are missing 100% of its values

# %%
IL = crimedata_reduced[crimedata_reduced['state']=='IL']
IL_df= pd.DataFrame(IL)
IL_df.columns[IL_df.isna().any()]

len(IL_df)
IL_df['rapes'].isna().sum()
IL_df['rapesPerPop'].isna().sum()
IL_df['ViolentCrimesPerPop'].isna().sum()

# %%
#IMPORTANT SECTION 

#IL_df['rapes'].fillna(IL_df['rapes'].mean(), inplace = True)
#IL_df['rapesPerPop'].fillna(IL_df['rapesPerPop'].mean(), inplace = True)
#IL_df['ViolentCrimesPerPop'].fillna(IL_df['ViolentCrimesPerPop'].mean(), inplace = True)

#IL_df.columns[IL_df.isna().any()]

#il_filtered = crimedata_reduced[crimedata_reduced['state'] != 'IL']
#crimedata_new = pd.concat([il_filtered, IL_df], ignore_index=True)

#Counter(crimedata_new[crimedata_new['state'] == "IL"].isna().any())
# Out:
# Index(['rapes', 'rapesPerPop', 'ViolentCrimesPerPop'], dtype='object')

# %% [markdown]
# STATE: GA

# %%
GA = crimedata_reduced[crimedata_reduced['state']=='GA']
GA_df= pd.DataFrame(GA)
GA_df.columns[GA_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: OK

# %%
OK = crimedata_reduced[crimedata_reduced['state']=='OK']
OK_df= pd.DataFrame(OK)
OK_df.columns[OK_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: TN

# %%
TN = crimedata_reduced[crimedata_reduced['state']=='TN']
TN_df= pd.DataFrame(TN)
TN_df.columns[TN_df.isna().any()]

len(TN_df)
TN_df['arsons'].isna().sum()
TN_df['arsonsPerPop'].isna().sum()
TN_df['nonViolPerPop'].isna().sum()

# %%
TN_df['arsons'].fillna(TN_df['arsons'].mean(), inplace = True)
TN_df['arsonsPerPop'].fillna(TN_df['arsonsPerPop'].mean(), inplace = True)
TN_df['nonViolPerPop'].fillna(TN_df['nonViolPerPop'].mean(), inplace = True)

TN_df.columns[WA_df.isna().any()]

tn_filtered = crimedata_reduced[crimedata_reduced['state'] != 'TN']
crimedata_new = pd.concat([tn_filtered, TN_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "TN"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: VA

# %%
VA = crimedata_reduced[crimedata_reduced['state']=='VA']
VA_df= pd.DataFrame(VA)
VA_df.columns[VA_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: OR

# %%
OR = crimedata_reduced[crimedata_reduced['state']=='OR']
OR_df= pd.DataFrame(OR)
OR_df.columns[OR_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: SC

# %%
SC = crimedata_reduced[crimedata_reduced['state']=='SC']
SC_df= pd.DataFrame(SC)
SC_df.columns[SC_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: KY

# %%
KY = crimedata_reduced[crimedata_reduced['state']=='KY']
KY_df= pd.DataFrame(KY)
KY_df.columns[KY_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: RI

# %%
RI = crimedata_reduced[crimedata_reduced['state']=='RI']
RI_df= pd.DataFrame(RI)
RI_df.columns[RI_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: AR

# %%
AR = crimedata_reduced[crimedata_reduced['state']=='AR']
AR_df= pd.DataFrame(AR)
AR_df.columns[AR_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: CO

# %%
CO = crimedata_reduced[crimedata_reduced['state']=='CO']
CO_df= pd.DataFrame(CO)
CO_df.columns[CO_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: UT

# %%
UT = crimedata_reduced[crimedata_reduced['state']=='UT']
UT_df= pd.DataFrame(UT)
UT_df.columns[UT_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: LA

# %%
LA = crimedata_reduced[crimedata_reduced['state']=='LA']
LA_df= pd.DataFrame(LA)
LA_df.columns[LA_df.isna().any()]

len(LA_df)
LA_df['arsons'].isna().sum()
LA_df['arsonsPerPop'].isna().sum()
LA_df['nonViolPerPop'].isna().sum()
# Out:
# 3

# %%
LA_df['arsons'].fillna(LA_df['arsons'].mean(), inplace = True)
LA_df['arsonsPerPop'].fillna(LA_df['arsonsPerPop'].mean(), inplace = True)
LA_df['nonViolPerPop'].fillna(LA_df['nonViolPerPop'].mean(), inplace = True)

LA_df.columns[LA_df.isna().any()]

la_filtered = crimedata_reduced[crimedata_reduced['state'] != 'LA']
crimedata_new = pd.concat([la_filtered, LA_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "LA"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: NH

# %%
NH = crimedata_reduced[crimedata_reduced['state']=='NH']
NH_df= pd.DataFrame(NH)
NH_df.columns[NH_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: MS

# %%
MS = crimedata_reduced[crimedata_reduced['state']=='MS']
MS_df= pd.DataFrame(MS)
MS_df.columns[MS_df.isna().any()]

len(MS_df)
MS_df['ViolentCrimesPerPop'].isna().sum()
# Out:
# 1

# %%
MS_df['ViolentCrimesPerPop'].fillna(MS_df['ViolentCrimesPerPop'].mean(), inplace = True)

MS_df.columns[MS_df.isna().any()]

ms_filtered = crimedata_reduced[crimedata_reduced['state'] != 'MS']
crimedata_new = pd.concat([ms_filtered, MS_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "MS"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: AZ

# %%
AZ = crimedata_reduced[crimedata_reduced['state']=='AZ']
AZ_df= pd.DataFrame(AZ)
AZ_df.columns[AZ_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: IA
# ************MISSING VALUES 0.85

# %%
IA = crimedata_reduced[crimedata_reduced['state']=='IA']
IA_df= pd.DataFrame(IA)
IA_df.columns[IA_df.isna().any()]

len(IA_df)
IA_df['arsons'].isna().sum()
IA_df['arsonsPerPop'].isna().sum()
IA_df['nonViolPerPop'].isna().sum()

# %% [markdown]
# STATE: ME

# %%
ME = crimedata_reduced[crimedata_reduced['state']=='ME']
ME_df= pd.DataFrame(ME)
ME_df.columns[ME_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: WV

# %%
WV = crimedata_reduced[crimedata_reduced['state']=='WV']
WV_df= pd.DataFrame(WV)
WV_df.columns[WV_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: MD
# ***********MISSING VALUES 0.25

# %%
MD = crimedata_reduced[crimedata_reduced['state']=='MD']
MD_df= pd.DataFrame(MD)
MD_df.columns[MD_df.isna().any()]

len(MD_df)
MD_df['arsons'].isna().sum()
MD_df['arsonsPerPop'].isna().sum()
MD_df['nonViolPerPop'].isna().sum()

# %% [markdown]
# STATE: NM

# %%
NM = crimedata_reduced[crimedata_reduced['state']=='NM']
NM_df= pd.DataFrame(NM)
NM_df.columns[NM_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: SD

# %%
SD = crimedata_reduced[crimedata_reduced['state']=='SD']
SD_df= pd.DataFrame(SD)
SD_df.columns[SD_df.isna().any()]

len(SD_df)
SD_df['arsons'].isna().sum()
SD_df['arsonsPerPop'].isna().sum()
SD_df['nonViolPerPop'].isna().sum()

# %%
SD_df['arsons'].fillna(SD_df['arsons'].mean(), inplace = True)
SD_df['arsonsPerPop'].fillna(SD_df['arsonsPerPop'].mean(), inplace = True)
SD_df['nonViolPerPop'].fillna(SD_df['nonViolPerPop'].mean(), inplace = True)

SD_df.columns[SD_df.isna().any()]

sd_filtered = crimedata_reduced[crimedata_reduced['state'] != 'SD']
crimedata_new = pd.concat([sd_filtered, SD_df], ignore_index=True)

Counter(crimedata_new[crimedata_new['state'] == "SD"].isna().any())
# Out:
# Counter({False: 122})

# %% [markdown]
# STATE: ND

# %%
ND = crimedata_reduced[crimedata_reduced['state']=='ND']
ND_df= pd.DataFrame(ND)
ND_df.columns[ND_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: WY

# %%
WY = crimedata_reduced[crimedata_reduced['state']=='WY']
WY_df= pd.DataFrame(WY)
WY_df.columns[WY_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: ID

# %%
ID = crimedata_reduced[crimedata_reduced['state']=='ID']
ID_df= pd.DataFrame(ID)
ID_df.columns[ID_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: NY
# **************MISSING VALUES 0.4

# %%
NY = crimedata_reduced[crimedata_reduced['state']=='NY']
NY_df= pd.DataFrame(NY)
NY_df.columns[NY_df.isna().any()]

len(NY_df)
NY_df['arsons'].isna().sum()
NY_df['arsonsPerPop'].isna().sum()
NY_df['nonViolPerPop'].isna().sum()
# Out:
# 17

# %% [markdown]
# STATE: VT
# ******************MISSING VALUES 1.0

# %%
VT = crimedata_reduced[crimedata_reduced['state']=='VT']
VT_df= pd.DataFrame(VT)
VT_df.columns[VT_df.isna().any()]

len(VT_df)
VT_df['arsons'].isna().sum()
VT_df['arsonsPerPop'].isna().sum()
VT_df['nonViolPerPop'].isna().sum()

# %% [markdown]
# STATE: AK

# %%
AK = crimedata_reduced[crimedata_reduced['state']=='AK']
AK_df= pd.DataFrame(AK)
AK_df.columns[AK_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: KS
# *********MISSING VALUES 1.0

# %%
#IMPORTANT SECTION
#ALL VALUES MISSING

KS = crimedata_reduced[crimedata_reduced['state']=='KS']
KS_df= pd.DataFrame(KS)
KS_df.columns[KS_df.isna().any()]

len(KS_df)
KS_df['arsons'].isna().sum()
KS_df['arsonsPerPop'].isna().sum()
KS_df['nonViolPerPop'].isna().sum()

# %% [markdown]
# STATE: DE

# %%
DE = crimedata_reduced[crimedata_reduced['state']=='DE']
DE_df= pd.DataFrame(DE)
DE_df.columns[DE_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# STATE: DC

# %%
DC = crimedata_reduced[crimedata_reduced['state']=='DC']
DC_df= pd.DataFrame(DC)
DC_df.columns[DC_df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# Now that we have gone through each state, we will check the entire dataset for any columns with missing values that we may have missed.

# %%
#Check whole dataset for columns with missing values
crimedata_new.columns[crimedata_new.isna().any()]
# Out:
# Index(['rapes', 'rapesPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop',
#        'nonViolPerPop'],
#       dtype='object')

# %%
#Check the total number of missing values for each column that was reported to have missing values

crimedata_new['rapes'].isna().sum()
crimedata_new['rapesPerPop'].isna().sum()
crimedata_new['arsons'].isna().sum()
crimedata_new['arsonsPerPop'].isna().sum()
crimedata_new['nonViolPerPop'].isna().sum()
# Out:
# 96

# %%
#Check datatypes again to confirm
crimedata_new.dtypes
# Out:
# communityname           object
# state                   object
# population               int64
# householdsize          float64
# racepctblack           float64
#                         ...
# autoTheftPerPop        float64
# arsons                 float64
# arsonsPerPop           float64
# ViolentCrimesPerPop    float64
# nonViolPerPop          float64
# Length: 122, dtype: object

# %% [markdown]
# Check the ranges of our target variables:

# %%
print(crimedata_new['murdPerPop'].min())
print(crimedata_new['murdPerPop'].max())
# Out:
# 0.0
# 91.09

# %%
print(crimedata_new['rapesPerPop'].min())
print(crimedata_new['rapesPerPop'].max())
# Out:
# 0.0
# 401.35

# %%
print(crimedata_new['robbbPerPop'].min())
print(crimedata_new['robbbPerPop'].max())
# Out:
# 0.0
# 2264.13

# %%
print(crimedata_new['burglPerPop'].min())
print(crimedata_new['burglPerPop'].max())
# Out:
# 16.92
# 11881.02

# %%
print(crimedata_new['assaultPerPop'].min())
print(crimedata_new['assaultPerPop'].max())
# Out:
# 0.0
# 4932.5

# %%
print(crimedata_new['larcPerPop'].min())
print(crimedata_new['larcPerPop'].max())
# Out:
# 77.86
# 25910.55

# %%
print(crimedata_new['autoTheftPerPop'].min())
print(crimedata_new['autoTheftPerPop'].max())
# Out:
# 6.55
# 4968.59

# %%
print(crimedata_new['arsonsPerPop'].min())
print(crimedata_new['arsonsPerPop'].max())
# Out:
# 0.0
# 436.37

# %% [markdown]
# Run a correlation matrix on the entire dataset:

# %%
pd.set_option('display.max_rows', None)

#Run correlation matrix
crime_corr = crimedata_new.corr(numeric_only=True)

# %%
#Unstack the matrix and sort the values from lowest to highest so we can clearly see the most negatively and positively correlated pairs
sorted_mat = crime_corr.unstack().sort_values()
sorted_mat
# Out:
# PctNotSpeakEnglWell    PctSpeakEnglOnly        -0.927588
# PctSpeakEnglOnly       PctNotSpeakEnglWell     -0.927588
#  racePctHisp           PctSpeakEnglOnly        -0.910258
# PctSpeakEnglOnly        racePctHisp            -0.910258
# pctWWage               pctWSocSec              -0.902436
# pctWSocSec             pctWWage                -0.902436
# PctForeignBorn         PctSpeakEnglOnly        -0.866879
# PctSpeakEnglOnly       PctForeignBorn          -0.866879
# PctKidsBornNeverMar    PctKids2Par             -0.865989
# PctKids2Par            PctKidsBornNeverMar     -0.865989
# PctKidsBornNeverMar    PctFam2Par              -0.846602
# PctFam2Par             PctKidsBornNeverMar     -0.846602
# pctWWage                agePct65up             -0.833639
#  agePct65up            pctWWage                -0.833639
# PctOccupManu           PctOccupMgmtProf        -0.827248
# PctOccupMgmtProf       PctOccupManu            -0.827248
# PctKidsBornNeverMar    PctYoungKids2Par        -0.822351
# PctYoungKids2Par       PctKidsBornNeverMar     -0.822351
# racepctblack           racePctWhite            -0.820605
# racePctWhite           racepctblack            -0.820605
# PctRecImmig10          PctSpeakEnglOnly        -0.815101
# PctSpeakEnglOnly       PctRecImmig10           -0.815101
#                        PctPersDenseHous        -0.811036
# PctPersDenseHous       PctSpeakEnglOnly        -0.811036
# PctKidsBornNeverMar    PctTeen2Par             -0.810672
# PctTeen2Par            PctKidsBornNeverMar     -0.810672
# PctKidsBornNeverMar    racePctWhite            -0.804595
# racePctWhite           PctKidsBornNeverMar     -0.804595
# PctSpeakEnglOnly       PctRecImmig8            -0.797763
# PctRecImmig8           PctSpeakEnglOnly        -0.797763
#  pctWPubAsst           PctYoungKids2Par        -0.794982
# PctYoungKids2Par        pctWPubAsst            -0.794982
# PctHousLess3BR         PctPersOwnOccup         -0.792567
# PctPersOwnOccup        PctHousLess3BR          -0.792567
# PctHousLess3BR         PctHousOwnOcc           -0.789921
# PctHousOwnOcc          PctHousLess3BR          -0.789921
# PctRecImmig5           PctSpeakEnglOnly        -0.783282
# PctSpeakEnglOnly       PctRecImmig5            -0.783282
# PctOccupManu           PctBSorMore             -0.781612
# PctBSorMore            PctOccupManu            -0.781612
# pctWInvInc             PctNotHSGrad            -0.780713
# PctNotHSGrad           pctWInvInc              -0.780713
# PctKids2Par             pctWPubAsst            -0.775207
#  pctWPubAsst           PctKids2Par             -0.775207
# PctHousLess3BR         MedNumBR                -0.770426
# MedNumBR               PctHousLess3BR          -0.770426
# PctFam2Par             TotalPctDiv             -0.768230
# TotalPctDiv            PctFam2Par              -0.768230
# PctPopUnderPov         PctYoungKids2Par        -0.765317
# PctYoungKids2Par       PctPopUnderPov          -0.765317
# PctKids2Par            PctPopUnderPov          -0.764359
# PctPopUnderPov         PctKids2Par             -0.764359
# PctFam2Par              pctWPubAsst            -0.760422
#  pctWPubAsst           PctFam2Par              -0.760422
# PctOccupMgmtProf       PctNotHSGrad            -0.758476
# PctNotHSGrad           PctOccupMgmtProf        -0.758476
#  medIncome             PctPopUnderPov          -0.758372
# PctPopUnderPov          medIncome              -0.758372
# PctRecentImmig         PctSpeakEnglOnly        -0.758220
# PctSpeakEnglOnly       PctRecentImmig          -0.758220
# PctFam2Par             FemalePctDiv            -0.755638
# FemalePctDiv           PctFam2Par              -0.755638
# PctHousNoPhone         pctWInvInc              -0.752296
# pctWInvInc             PctHousNoPhone          -0.752296
# PctPopUnderPov         PctFam2Par              -0.752096
# PctFam2Par             PctPopUnderPov          -0.752096
# TotalPctDiv            PctKids2Par             -0.751692
# PctKids2Par            TotalPctDiv             -0.751692
# PctNotHSGrad           PctBSorMore             -0.751544
# PctBSorMore            PctNotHSGrad            -0.751544
#  pctWPubAsst           pctWInvInc              -0.743427
# pctWInvInc              pctWPubAsst            -0.743427
# PctEmploy              pctWSocSec              -0.741854
# pctWSocSec             PctEmploy               -0.741854
# racepctblack           PctKids2Par             -0.740483
# PctKids2Par            racepctblack            -0.740483
#                        FemalePctDiv            -0.740435
# FemalePctDiv           PctKids2Par             -0.740435
# MalePctDivorce         PctFam2Par              -0.738118
# PctFam2Par             MalePctDivorce          -0.738118
# PctPopUnderPov         medFamInc               -0.729212
# medFamInc              PctPopUnderPov          -0.729212
# ViolentCrimesPerPop    PctKids2Par             -0.727427
# PctKids2Par            ViolentCrimesPerPop     -0.727427
# PctYoungKids2Par       PctHousNoPhone          -0.726080
# PctHousNoPhone         PctYoungKids2Par        -0.726080
# PctKids2Par            PctHousNoPhone          -0.723081
# PctHousNoPhone         PctKids2Par             -0.723081
# PctKids2Par            MalePctDivorce          -0.722034
# MalePctDivorce         PctKids2Par             -0.722034
# PctUnemployed          pctWInvInc              -0.717577
# pctWInvInc             PctUnemployed           -0.717577
#                        PctPopUnderPov          -0.716797
# PctPopUnderPov         pctWInvInc              -0.716797
# PctNotHSGrad           medFamInc               -0.710084
# medFamInc              PctNotHSGrad            -0.710084
# racepctblack           PctFam2Par              -0.709876
# PctFam2Par             racepctblack            -0.709876
# racePctWhite           robbbPerPop             -0.709786
# robbbPerPop            racePctWhite            -0.709786
# PctHousNoPhone         medFamInc               -0.707043
# medFamInc              PctHousNoPhone          -0.707043
# racepctblack           PctTeen2Par             -0.703863
# PctTeen2Par            racepctblack            -0.703863
# PctUnemployed          PctYoungKids2Par        -0.702484
# PctYoungKids2Par       PctUnemployed           -0.702484
# PctEmploy              PctPopUnderPov          -0.700901
# PctPopUnderPov         PctEmploy               -0.700901
# PctTeen2Par            TotalPctDiv             -0.698362
# TotalPctDiv            PctTeen2Par             -0.698362
# ViolentCrimesPerPop    PctFam2Par              -0.698153
# PctFam2Par             ViolentCrimesPerPop     -0.698153
# TotalPctDiv            PctYoungKids2Par        -0.698075
# PctYoungKids2Par       TotalPctDiv             -0.698075
# PctHousNoPhone          medIncome              -0.697365
#  medIncome             PctHousNoPhone          -0.697365
# PctSpeakEnglOnly       PctLargHouseFam         -0.693044
# PctLargHouseFam        PctSpeakEnglOnly        -0.693044
# PctTeen2Par            FemalePctDiv            -0.692040
# FemalePctDiv           PctTeen2Par             -0.692040
# PctUnemployed          PctKids2Par             -0.691023
# PctKids2Par            PctUnemployed           -0.691023
# PctHousNoPhone         PctFam2Par              -0.687683
# PctFam2Par             PctHousNoPhone          -0.687683
# burglPerPop            PctKids2Par             -0.687077
# PctKids2Par            burglPerPop             -0.687077
# PctYoungKids2Par       MalePctDivorce          -0.680779
# MalePctDivorce         PctYoungKids2Par        -0.680779
# PctTeen2Par            PctPopUnderPov          -0.679824
# PctPopUnderPov         PctTeen2Par             -0.679824
# PctKids2Par            PctNotHSGrad            -0.679091
# PctNotHSGrad           PctKids2Par             -0.679091
# FemalePctDiv           PctYoungKids2Par        -0.677886
# PctYoungKids2Par       FemalePctDiv            -0.677886
# PctOccupManu           pctWInvInc              -0.676975
# pctWInvInc             PctOccupManu            -0.676975
# PctUnemployed          PctEmploy               -0.676430
# PctEmploy              PctUnemployed           -0.676430
# ViolentCrimesPerPop    racePctWhite            -0.676324
# racePctWhite           ViolentCrimesPerPop     -0.676324
# RentLowQ               PctHousNoPhone          -0.672009
# PctHousNoPhone         RentLowQ                -0.672009
# PctUnemployed          PctFam2Par              -0.671801
# PctFam2Par             PctUnemployed           -0.671801
# robbbPerPop            PctKids2Par             -0.670866
# PctKids2Par            robbbPerPop             -0.670866
#  medIncome             PctNotHSGrad            -0.670619
# PctNotHSGrad            medIncome              -0.670619
# PctLargHouseOccup      PctSpeakEnglOnly        -0.670120
# PctSpeakEnglOnly       PctLargHouseOccup       -0.670120
# PctKids2Par            nonViolPerPop           -0.669238
# nonViolPerPop          PctKids2Par             -0.669238
# racepctblack           PctYoungKids2Par        -0.668200
# PctYoungKids2Par       racepctblack            -0.668200
# murdPerPop             racePctWhite            -0.666004
# racePctWhite           murdPerPop              -0.666004
# pctWInvInc             PctLess9thGrade         -0.665737
# PctLess9thGrade        pctWInvInc              -0.665737
# MalePctDivorce         PctTeen2Par             -0.664265
# PctTeen2Par            MalePctDivorce          -0.664265
# burglPerPop            PctFam2Par              -0.663848
# PctFam2Par             burglPerPop             -0.663848
# RentMedian             PctHousNoPhone          -0.663838
# PctHousNoPhone         RentMedian              -0.663838
# PctFam2Par             nonViolPerPop           -0.662120
# nonViolPerPop          PctFam2Par              -0.662120
#  pctWPubAsst           PctTeen2Par             -0.659189
# PctTeen2Par             pctWPubAsst            -0.659189
# ViolentCrimesPerPop    PctYoungKids2Par        -0.658005
# PctYoungKids2Par       ViolentCrimesPerPop     -0.658005
# RentHighQ              PctHousNoPhone          -0.656967
# PctHousNoPhone         RentHighQ               -0.656967
# PctOccupManu           medFamInc               -0.656885
# medFamInc              PctOccupManu            -0.656885
#                         pctWPubAsst            -0.656445
#  pctWPubAsst           medFamInc               -0.656445
#  perCapInc             PctOccupManu            -0.655985
# PctOccupManu            perCapInc              -0.655985
# PctTeen2Par            ViolentCrimesPerPop     -0.655068
# ViolentCrimesPerPop    PctTeen2Par             -0.655068
# PctNotHSGrad            perCapInc              -0.653065
#  perCapInc             PctNotHSGrad            -0.653065
# PctHousNoPhone         MedRent                 -0.652215
# MedRent                PctHousNoPhone          -0.652215
# PctFam2Par             robbbPerPop             -0.651478
# robbbPerPop            PctFam2Par              -0.651478
# PctPopUnderPov         RentLowQ                -0.648443
# RentLowQ               PctPopUnderPov          -0.648443
# PctKids2Par            assaultPerPop           -0.647687
# assaultPerPop          PctKids2Par             -0.647687
# PctPopUnderPov         MedRent                 -0.646506
# MedRent                PctPopUnderPov          -0.646506
# PctNotHSGrad           PctYoungKids2Par        -0.646471
# PctYoungKids2Par       PctNotHSGrad            -0.646471
#  pctWPubAsst           PctEmploy               -0.644942
# PctEmploy               pctWPubAsst            -0.644942
# FemalePctDiv           pctWInvInc              -0.644531
# pctWInvInc             FemalePctDiv            -0.644531
# PctFam2Par             PctHousLess3BR          -0.644479
# PctHousLess3BR         PctFam2Par              -0.644479
# murdPerPop             PctKids2Par             -0.640889
# PctKids2Par            murdPerPop              -0.640889
# PctPersOwnOccup        PctPopUnderPov          -0.639182
# PctPopUnderPov         PctPersOwnOccup         -0.639182
# PctTeen2Par            robbbPerPop             -0.639028
# robbbPerPop            PctTeen2Par             -0.639028
# RentMedian             PctPopUnderPov          -0.639022
# PctPopUnderPov         RentMedian              -0.639022
# whitePerCap            PctOccupManu            -0.637627
# PctOccupManu           whitePerCap             -0.637627
#  perCapInc             PctPopUnderPov          -0.637168
# PctPopUnderPov          perCapInc              -0.637168
# pctWInvInc             TotalPctDiv             -0.636906
# TotalPctDiv            pctWInvInc              -0.636906
# PctUnemployed          medFamInc               -0.636091
# medFamInc              PctUnemployed           -0.636091
#  agePct65up            PersPerOwnOccHous       -0.634781
# PersPerOwnOccHous       agePct65up             -0.634781
# burglPerPop            PctTeen2Par             -0.634761
# PctTeen2Par            burglPerPop             -0.634761
# PctYoungKids2Par       burglPerPop             -0.633771
# burglPerPop            PctYoungKids2Par        -0.633771
#  medIncome              pctWPubAsst            -0.633009
#  pctWPubAsst            medIncome              -0.633009
# PctKidsBornNeverMar    pctWInvInc              -0.627802
# pctWInvInc             PctKidsBornNeverMar     -0.627802
# PctHousLess3BR         PctKids2Par             -0.625435
# PctKids2Par            PctHousLess3BR          -0.625435
#  agePct65up            PctEmploy               -0.622859
# PctEmploy               agePct65up             -0.622859
# PctTeen2Par            nonViolPerPop           -0.622792
# nonViolPerPop          PctTeen2Par             -0.622792
# assaultPerPop          PctFam2Par              -0.622293
# PctFam2Par             assaultPerPop           -0.622293
# PctNotHSGrad           PctFam2Par              -0.622188
# PctFam2Par             PctNotHSGrad            -0.622188
# RentHighQ              PctPopUnderPov          -0.621935
# PctPopUnderPov         RentHighQ               -0.621935
# PctHousOwnOcc          MalePctNevMarr          -0.617422
# MalePctNevMarr         PctHousOwnOcc           -0.617422
# PctNotHSGrad           PctEmploy               -0.617251
# PctEmploy              PctNotHSGrad            -0.617251
# PctHousLess3BR          medIncome              -0.616395
#  medIncome             PctHousLess3BR          -0.616395
# nonViolPerPop          PctYoungKids2Par        -0.615673
# PctYoungKids2Par       nonViolPerPop           -0.615673
# PctUnemployed           medIncome              -0.614694
#  medIncome             PctUnemployed           -0.614694
# PctFam2Par             murdPerPop              -0.613577
# murdPerPop             PctFam2Par              -0.613577
# PctPersOwnOccup        FemalePctDiv            -0.611651
# FemalePctDiv           PctPersOwnOccup         -0.611651
# PctOccupManu            medIncome              -0.608792
#  medIncome             PctOccupManu            -0.608792
# PctYoungKids2Par       assaultPerPop           -0.606742
# assaultPerPop          PctYoungKids2Par        -0.606742
# PctKidsBornNeverMar    PctPersOwnOccup         -0.605620
# PctPersOwnOccup        PctKidsBornNeverMar     -0.605620
# PctHousNoPhone         PctTeen2Par             -0.604983
# PctTeen2Par            PctHousNoPhone          -0.604983
# MalePctDivorce         pctWInvInc              -0.600100
# pctWInvInc             MalePctDivorce          -0.600100
#  perCapInc             PctHousNoPhone          -0.600072
# PctHousNoPhone          perCapInc              -0.600072
# racePctWhite            pctWPubAsst            -0.598154
#  pctWPubAsst           racePctWhite            -0.598154
# PctOccupMgmtProf       PctLess9thGrade         -0.597041
# PctLess9thGrade        PctOccupMgmtProf        -0.597041
# PctYoungKids2Par       murdPerPop              -0.591170
# murdPerPop             PctYoungKids2Par        -0.591170
# PctPersOwnOccup        TotalPctDiv             -0.590659
# TotalPctDiv            PctPersOwnOccup         -0.590659
# PctTeen2Par            murdPerPop              -0.590444
# murdPerPop             PctTeen2Par             -0.590444
# RentHighQ              PctOccupManu            -0.590136
# PctOccupManu           RentHighQ               -0.590136
# PctLess9thGrade        medFamInc               -0.589924
# medFamInc              PctLess9thGrade         -0.589924
# whitePerCap            PctNotHSGrad            -0.589170
# PctNotHSGrad           whitePerCap             -0.589170
# PctHousNoPhone         PctEmploy               -0.588288
# PctEmploy              PctHousNoPhone          -0.588288
# PctPersDenseHous       racePctWhite            -0.588118
# racePctWhite           PctPersDenseHous        -0.588118
# MalePctNevMarr         PctPersOwnOccup         -0.587865
# PctPersOwnOccup        MalePctNevMarr          -0.587865
# robbbPerPop            PctYoungKids2Par        -0.586755
# PctYoungKids2Par       robbbPerPop             -0.586755
# PctUnemployed           perCapInc              -0.586014
#  perCapInc             PctUnemployed           -0.586014
# PctTeen2Par            PctHousLess3BR          -0.585926
# PctHousLess3BR         PctTeen2Par             -0.585926
# assaultPerPop          PctTeen2Par             -0.580174
# PctTeen2Par            assaultPerPop           -0.580174
#  perCapInc              pctWPubAsst            -0.580153
#  pctWPubAsst            perCapInc              -0.580153
# PersPerFam             PctSpeakEnglOnly        -0.579869
# PctSpeakEnglOnly       PersPerFam              -0.579869
# PctPopUnderPov         PctHousOwnOcc           -0.579256
# PctHousOwnOcc          PctPopUnderPov          -0.579256
#  agePct65up            householdsize           -0.578092
# householdsize           agePct65up             -0.578092
# PctUnemployed          PctTeen2Par             -0.577376
# PctTeen2Par            PctUnemployed           -0.577376
# PctLess9thGrade        PctBSorMore             -0.577203
# PctBSorMore            PctLess9thGrade         -0.577203
# PctOccupManu           RentMedian              -0.575103
# RentMedian             PctOccupManu            -0.575103
# PctLess9thGrade        PctSpeakEnglOnly        -0.574739
# PctSpeakEnglOnly       PctLess9thGrade         -0.574739
# PctHousOwnOcc          FemalePctDiv            -0.573870
# FemalePctDiv           PctHousOwnOcc           -0.573870
# rapesPerPop            PctFam2Par              -0.571361
# PctFam2Par             rapesPerPop             -0.571361
# TotalPctDiv            medFamInc               -0.569547
# medFamInc              TotalPctDiv             -0.569547
# PctKids2Par            rapesPerPop             -0.569033
# rapesPerPop            PctKids2Par             -0.569033
# PctUnemployed          PctOccupMgmtProf        -0.569011
# PctOccupMgmtProf       PctUnemployed           -0.569011
# MedRent                PctOccupManu            -0.567087
# PctOccupManu           MedRent                 -0.567087
#  pctWPubAsst           PctOccupMgmtProf        -0.566584
# PctOccupMgmtProf        pctWPubAsst            -0.566584
# MalePctDivorce         medFamInc               -0.566080
# medFamInc              MalePctDivorce          -0.566080
# PctSpeakEnglOnly       PersPerRentOccHous      -0.565765
# PersPerRentOccHous     PctSpeakEnglOnly        -0.565765
# PctHousOwnOcc          PctKidsBornNeverMar     -0.565750
# PctKidsBornNeverMar    PctHousOwnOcc           -0.565750
# agePct12t29            PctSameHouse85          -0.565695
# PctSameHouse85         agePct12t29             -0.565695
#  medIncome             TotalPctDiv             -0.564934
# TotalPctDiv             medIncome              -0.564934
# racePctWhite           burglPerPop             -0.564292
# burglPerPop            racePctWhite            -0.564292
# racePctWhite           assaultPerPop           -0.563777
# assaultPerPop          racePctWhite            -0.563777
# PctHousLess3BR         medFamInc               -0.563047
# medFamInc              PctHousLess3BR          -0.563047
#  agePct65up            PersPerOccupHous        -0.562139
# PersPerOccupHous        agePct65up             -0.562139
#  medIncome             MalePctDivorce          -0.562002
# MalePctDivorce          medIncome              -0.562002
# RentLowQ               PctNotHSGrad            -0.560853
# PctNotHSGrad           RentLowQ                -0.560853
# ViolentCrimesPerPop    pctWInvInc              -0.557654
# pctWInvInc             ViolentCrimesPerPop     -0.557654
# RentLowQ               PctOccupManu            -0.557449
# PctOccupManu           RentLowQ                -0.557449
# PctYoungKids2Par       rapesPerPop             -0.557436
# rapesPerPop            PctYoungKids2Par        -0.557436
#  medIncome             PctLess9thGrade         -0.557086
# PctLess9thGrade         medIncome              -0.557086
# racePctWhite           autoTheftPerPop         -0.556910
# autoTheftPerPop        racePctWhite            -0.556910
# pctWWage                pctWPubAsst            -0.556863
#  pctWPubAsst           pctWWage                -0.556863
# PctSameCity85          agePct12t29             -0.556742
# agePct12t29            PctSameCity85           -0.556742
# PctHousOwnOcc          TotalPctDiv             -0.556167
# TotalPctDiv            PctHousOwnOcc           -0.556167
# racePctWhite           PctLargHouseFam         -0.555191
# PctLargHouseFam        racePctWhite            -0.555191
# agePct12t29            PctHousOwnOcc           -0.555098
# PctHousOwnOcc          agePct12t29             -0.555098
# PctBSorMore             pctWPubAsst            -0.554810
#  pctWPubAsst           PctBSorMore             -0.554810
# PctKids2Par            PctVacantBoarded        -0.554250
# PctVacantBoarded       PctKids2Par             -0.554250
# pctWWage               pctWRetire              -0.552375
# pctWRetire             pctWWage                -0.552375
# PctFam2Par             larcPerPop              -0.549639
# larcPerPop             PctFam2Par              -0.549639
# medFamInc              FemalePctDiv            -0.547925
# FemalePctDiv           medFamInc               -0.547925
# PersPerFam              agePct65up             -0.547636
#  agePct65up            PersPerFam              -0.547636
# PctNotHSGrad           pctWWage                -0.547234
# pctWWage               PctNotHSGrad            -0.547234
# racePctWhite           PctPopUnderPov          -0.547048
# PctPopUnderPov         racePctWhite            -0.547048
# OwnOccHiQuart          PctOccupManu            -0.546454
# PctOccupManu           OwnOccHiQuart           -0.546454
# PctUnemployed          PctBSorMore             -0.545808
# PctBSorMore            PctUnemployed           -0.545808
# RentMedian             PctNotHSGrad            -0.545374
# PctNotHSGrad           RentMedian              -0.545374
# PctPersOwnOccup        agePct12t29             -0.545068
# agePct12t29            PctPersOwnOccup         -0.545068
# larcPerPop             PctKids2Par             -0.545059
# PctKids2Par            larcPerPop              -0.545059
# MalePctDivorce         PctPersOwnOccup         -0.545036
# PctPersOwnOccup        MalePctDivorce          -0.545036
# PctHousNoPhone         OwnOccLowQuart          -0.544386
# OwnOccLowQuart         PctHousNoPhone          -0.544386
# PctLess9thGrade         perCapInc              -0.543935
#  perCapInc             PctLess9thGrade         -0.543935
# PctYoungKids2Par       PctHousLess3BR          -0.542840
# PctHousLess3BR         PctYoungKids2Par        -0.542840
# whitePerCap            PctPopUnderPov          -0.542530
# PctPopUnderPov         whitePerCap             -0.542530
# RentHighQ              PctNotHSGrad            -0.541586
# PctNotHSGrad           RentHighQ               -0.541586
# pctWSocSec             PersPerOwnOccHous       -0.541172
# PersPerOwnOccHous      pctWSocSec              -0.541172
#  medIncome             FemalePctDiv            -0.540722
# FemalePctDiv            medIncome              -0.540722
# PctUnemployed          racePctWhite            -0.539588
# racePctWhite           PctUnemployed           -0.539588
# PctOccupMgmtProf       PctHousNoPhone          -0.539534
# PctHousNoPhone         PctOccupMgmtProf        -0.539534
# PctNotHSGrad           MedRent                 -0.535414
# MedRent                PctNotHSGrad            -0.535414
# PctVacantBoarded       PctYoungKids2Par        -0.535253
# PctYoungKids2Par       PctVacantBoarded        -0.535253
# PctKids2Par            PctLess9thGrade         -0.534775
# PctLess9thGrade        PctKids2Par             -0.534775
# PctVacantBoarded       PctFam2Par              -0.533419
# PctFam2Par             PctVacantBoarded        -0.533419
# assaultPerPop          pctWInvInc              -0.532222
# pctWInvInc             assaultPerPop           -0.532222
# PctOccupManu           PctYoungKids2Par        -0.532063
# PctYoungKids2Par       PctOccupManu            -0.532063
# PctEmploy              PctLess9thGrade         -0.531317
# PctLess9thGrade        PctEmploy               -0.531317
# agePct16t24            PctSameCity85           -0.530592
# PctSameCity85          agePct16t24             -0.530592
# PctPersOwnOccup         pctWPubAsst            -0.528717
#  pctWPubAsst           PctPersOwnOccup         -0.528717
# pctWInvInc             burglPerPop             -0.528480
# burglPerPop            pctWInvInc              -0.528480
# OwnOccMedVal           PctHousNoPhone          -0.527730
# PctHousNoPhone         OwnOccMedVal            -0.527730
# PctImmigRec10          PctPersOwnOccup         -0.526075
# PctPersOwnOccup        PctImmigRec10           -0.526075
# PctPersDenseHous       pctWInvInc              -0.525131
# pctWInvInc             PctPersDenseHous        -0.525131
# OwnOccMedVal           PctOccupManu            -0.524132
# PctOccupManu           OwnOccMedVal            -0.524132
# PctPopUnderPov         pctWWage                -0.522483
# pctWWage               PctPopUnderPov          -0.522483
# rapesPerPop            PctTeen2Par             -0.521725
# PctTeen2Par            rapesPerPop             -0.521725
# OwnOccHiQuart          PctHousNoPhone          -0.520873
# PctHousNoPhone         OwnOccHiQuart           -0.520873
# RentLowQ                pctWPubAsst            -0.518926
#  pctWPubAsst           RentLowQ                -0.518926
# whitePerCap            PctUnemployed           -0.517511
# PctUnemployed          whitePerCap             -0.517511
# PctYoungKids2Par       larcPerPop              -0.516619
# larcPerPop             PctYoungKids2Par        -0.516619
# PctTeen2Par            PctNotHSGrad            -0.516088
# PctNotHSGrad           PctTeen2Par             -0.516088
# OwnOccLowQuart         PctOccupManu            -0.515479
# PctOccupManu           OwnOccLowQuart          -0.515479
# PctSameHouse85         PctImmigRec10           -0.514806
# PctImmigRec10          PctSameHouse85          -0.514806
# whitePerCap            PctHousNoPhone          -0.514738
# PctHousNoPhone         whitePerCap             -0.514738
# PctHousOwnOcc          MalePctDivorce          -0.514539
# MalePctDivorce         PctHousOwnOcc           -0.514539
# PctBSorMore            PctHousNoPhone          -0.514317
# PctHousNoPhone         PctBSorMore             -0.514317
# PctUnemployed          pctWWage                -0.511972
# pctWWage               PctUnemployed           -0.511972
# PctHousNoPhone         PctPersOwnOccup         -0.510531
# PctPersOwnOccup        PctHousNoPhone          -0.510531
# PctTeen2Par            larcPerPop              -0.509536
# larcPerPop             PctTeen2Par             -0.509536
# RentLowQ               PctUnemployed           -0.508959
# PctUnemployed          RentLowQ                -0.508959
# PersPerRentOccHous     pctWInvInc              -0.508945
# pctWInvInc             PersPerRentOccHous      -0.508945
# PctPersOwnOccup        ViolentCrimesPerPop     -0.507332
# ViolentCrimesPerPop    PctPersOwnOccup         -0.507332
# nonViolPerPop          PctPersOwnOccup         -0.505299
# PctPersOwnOccup        nonViolPerPop           -0.505299
# OwnOccQrange           PctOccupManu            -0.504992
# PctOccupManu           OwnOccQrange            -0.504992
# OwnOccLowQuart         PctPopUnderPov          -0.504951
# PctPopUnderPov         OwnOccLowQuart          -0.504951
# PctHousNoPhone         pctWWage                -0.504916
# pctWWage               PctHousNoPhone          -0.504916
# racepctblack           pctWInvInc              -0.504866
# pctWInvInc             racepctblack            -0.504866
# PctImmigRec8           PctPersOwnOccup         -0.504335
# PctPersOwnOccup        PctImmigRec8            -0.504335
# PctLess9thGrade        PctYoungKids2Par        -0.503845
# PctYoungKids2Par       PctLess9thGrade         -0.503845
# PctImmigRec8           PctSameHouse85          -0.503344
# PctSameHouse85         PctImmigRec8            -0.503344
# PctKids2Par            PctOccupManu            -0.502827
# PctOccupManu           PctKids2Par             -0.502827
# PctHousOwnOcc          PctImmigRec10           -0.502584
# PctImmigRec10          PctHousOwnOcc           -0.502584
#  pctWPubAsst           MedRent                 -0.501784
# MedRent                 pctWPubAsst            -0.501784
# PctBSorMore            MalePctDivorce          -0.499973
# MalePctDivorce         PctBSorMore             -0.499973
# PctSpeakEnglOnly       PopDens                 -0.498015
# PopDens                PctSpeakEnglOnly        -0.498015
# PctHousNoPhone         racePctWhite            -0.496830
# racePctWhite           PctHousNoPhone          -0.496830
# RentMedian              pctWPubAsst            -0.496736
#  pctWPubAsst           RentMedian              -0.496736
# racePctWhite           PctNotHSGrad            -0.494350
# PctNotHSGrad           racePctWhite            -0.494350
#  pctWPubAsst           whitePerCap             -0.494059
# whitePerCap             pctWPubAsst            -0.494059
# pctWInvInc             nonViolPerPop           -0.493419
# nonViolPerPop          pctWInvInc              -0.493419
# robbbPerPop            PctPersOwnOccup         -0.492807
# PctPersOwnOccup        robbbPerPop             -0.492807
# murdPerPop             pctWInvInc              -0.491301
# pctWInvInc             murdPerPop              -0.491301
# PctHousOwnOcc          PctImmigRec8            -0.489378
# PctImmigRec8           PctHousOwnOcc           -0.489378
# PctSpeakEnglOnly       PersPerOccupHous        -0.489071
# PersPerOccupHous       PctSpeakEnglOnly        -0.489071
# PctVacantBoarded       racePctWhite            -0.487907
# racePctWhite           PctVacantBoarded        -0.487907
# RentHighQ               pctWPubAsst            -0.487614
#  pctWPubAsst           RentHighQ               -0.487614
# pctWInvInc             PctHousLess3BR          -0.487532
# PctHousLess3BR         pctWInvInc              -0.487532
# PctOccupMgmtProf       MalePctDivorce          -0.487131
# MalePctDivorce         PctOccupMgmtProf        -0.487131
# OwnOccMedVal           PctPopUnderPov          -0.487109
# PctPopUnderPov         OwnOccMedVal            -0.487109
# racePctWhite           nonViolPerPop           -0.487033
# nonViolPerPop          racePctWhite            -0.487033
# whitePerCap            PctLess9thGrade         -0.486203
# PctLess9thGrade        whitePerCap             -0.486203
# PctTeen2Par            PctVacantBoarded        -0.486106
# PctVacantBoarded       PctTeen2Par             -0.486106
# PctUnemployed          RentMedian              -0.485865
# RentMedian             PctUnemployed           -0.485865
# PctLargHouseFam        pctWInvInc              -0.485859
# pctWInvInc             PctLargHouseFam         -0.485859
# PctKids2Par            autoTheftPerPop         -0.485558
# autoTheftPerPop        PctKids2Par             -0.485558
# PctForeignBorn         PctBornSameState        -0.485209
# PctBornSameState       PctForeignBorn          -0.485209
# MedYrHousBuilt         PctSameHouse85          -0.484682
# PctSameHouse85         MedYrHousBuilt          -0.484682
# PctUnemployed          MedRent                 -0.482430
# MedRent                PctUnemployed           -0.482430
# PctRecImmig8           PctBornSameState        -0.480782
# PctBornSameState       PctRecImmig8            -0.480782
# PctPersOwnOccup        PctImmigRec5            -0.480569
# PctImmigRec5           PctPersOwnOccup         -0.480569
#                        PctSameHouse85          -0.479528
# PctSameHouse85         PctImmigRec5            -0.479528
# PctOccupManu           PctFam2Par              -0.478383
# PctFam2Par             PctOccupManu            -0.478383
# PctPopUnderPov         OwnOccHiQuart           -0.477916
# OwnOccHiQuart          PctPopUnderPov          -0.477916
# agePct12t29             agePct65up             -0.476703
#  agePct65up            agePct12t29             -0.476703
# PctLargHouseOccup      racePctWhite            -0.475535
# racePctWhite           PctLargHouseOccup       -0.475535
# PctUnemployed          RentHighQ               -0.475530
# RentHighQ              PctUnemployed           -0.475530
# PctFam2Par             PctLess9thGrade         -0.475319
# PctLess9thGrade        PctFam2Par              -0.475319
# PctRecImmig5           PctBornSameState        -0.475075
# PctBornSameState       PctRecImmig5            -0.475075
#                        PctRecImmig10           -0.474867
# PctRecImmig10          PctBornSameState        -0.474867
# MedYrHousBuilt         pctWSocSec              -0.474610
# pctWSocSec             MedYrHousBuilt          -0.474610
# PctKidsBornNeverMar    medFamInc               -0.474266
# medFamInc              PctKidsBornNeverMar     -0.474266
# PctRecentImmig         PctBornSameState        -0.473467
# PctBornSameState       PctRecentImmig          -0.473467
# nonViolPerPop           medIncome              -0.473101
#  medIncome             nonViolPerPop           -0.473101
# PctPersOwnOccup        burglPerPop             -0.471812
# burglPerPop            PctPersOwnOccup         -0.471812
# PctBSorMore            TotalPctDiv             -0.471659
# TotalPctDiv            PctBSorMore             -0.471659
# HispPerCap             PctPopUnderPov          -0.471131
# PctPopUnderPov         HispPerCap              -0.471131
# PctWOFullPlumb         pctWInvInc              -0.471049
# pctWInvInc             PctWOFullPlumb          -0.471049
# PctImmigRec5           PctHousOwnOcc           -0.470649
# PctHousOwnOcc          PctImmigRec5            -0.470649
# PctEmplProfServ        PctEmplManu             -0.470100
# PctEmplManu            PctEmplProfServ         -0.470100
# PctLess9thGrade        RentLowQ                -0.469822
# RentLowQ               PctLess9thGrade         -0.469822
# racePctWhite           PersPerRentOccHous      -0.469421
# PersPerRentOccHous     racePctWhite            -0.469421
# agePct16t24            PctSameHouse85          -0.468582
# PctSameHouse85         agePct16t24             -0.468582
# MedOwnCostPctInc       PctBornSameState        -0.466661
# PctBornSameState       MedOwnCostPctInc        -0.466661
# nonViolPerPop          PctHousOwnOcc           -0.466257
# PctHousOwnOcc          nonViolPerPop           -0.466257
#  medIncome             PctKidsBornNeverMar     -0.466245
# PctKidsBornNeverMar     medIncome              -0.466245
#  pctWPubAsst           PctHousOwnOcc           -0.465836
# PctHousOwnOcc           pctWPubAsst            -0.465836
# FemalePctDiv           racePctWhite            -0.465327
# racePctWhite           FemalePctDiv            -0.465327
# TotalPctDiv            PctOccupMgmtProf        -0.465263
# PctOccupMgmtProf       TotalPctDiv             -0.465263
# MedYrHousBuilt         PctSameCity85           -0.464852
# PctSameCity85          MedYrHousBuilt          -0.464852
# PctHousOwnOcc          robbbPerPop             -0.463312
# robbbPerPop            PctHousOwnOcc           -0.463312
# autoTheftPerPop        PctFam2Par              -0.463095
# PctFam2Par             autoTheftPerPop         -0.463095
# nonViolPerPop          medFamInc               -0.462933
# medFamInc              nonViolPerPop           -0.462933
# rapesPerPop            pctWInvInc              -0.460423
# pctWInvInc             rapesPerPop             -0.460423
# OwnOccHiQuart          PctNotHSGrad            -0.459509
# PctNotHSGrad           OwnOccHiQuart           -0.459509
# PctPopUnderPov         PctOccupMgmtProf        -0.459406
# PctOccupMgmtProf       PctPopUnderPov          -0.459406
# racePctWhite           PctLess9thGrade         -0.458497
# PctLess9thGrade        racePctWhite            -0.458497
# agePct16t24            PctHousOwnOcc           -0.456332
# PctHousOwnOcc          agePct16t24             -0.456332
# PctEmplProfServ        PctOccupManu            -0.456121
# PctOccupManu           PctEmplProfServ         -0.456121
# PctHousOwnOcc          ViolentCrimesPerPop     -0.455363
# ViolentCrimesPerPop    PctHousOwnOcc           -0.455363
#  medIncome             larcPerPop              -0.455094
# larcPerPop              medIncome              -0.455094
# autoTheftPerPop        PctTeen2Par             -0.454369
# PctTeen2Par            autoTheftPerPop         -0.454369
# PctPersOwnOccup        PctUnemployed           -0.453812
# PctUnemployed          PctPersOwnOccup         -0.453812
# OwnOccLowQuart         PctNotHSGrad            -0.453407
# PctNotHSGrad           OwnOccLowQuart          -0.453407
# pctWSocSec             PersPerOccupHous        -0.452679
# PersPerOccupHous       pctWSocSec              -0.452679
# PctNotHSGrad           OwnOccMedVal            -0.451193
# OwnOccMedVal           PctNotHSGrad            -0.451193
# PctNotHSGrad           PctPersOwnOccup         -0.450311
# PctPersOwnOccup        PctNotHSGrad            -0.450311
# PctVacantBoarded       pctWInvInc              -0.449542
# pctWInvInc             PctVacantBoarded        -0.449542
# PctLess9thGrade        MedRent                 -0.448588
# MedRent                PctLess9thGrade         -0.448588
# RentMedian             PctLess9thGrade         -0.447423
# PctLess9thGrade        RentMedian              -0.447423
# PctPersOwnOccup        agePct16t24             -0.446484
# agePct16t24            PctPersOwnOccup         -0.446484
# PersPerOwnOccHous      MalePctDivorce          -0.445078
# MalePctDivorce         PersPerOwnOccHous       -0.445078
# PctPersDenseHous       PctPersOwnOccup         -0.444156
# PctPersOwnOccup        PctPersDenseHous        -0.444156
# pctWInvInc             robbbPerPop             -0.443563
# robbbPerPop            pctWInvInc              -0.443563
# HispPerCap             PctOccupManu            -0.443013
# PctOccupManu           HispPerCap              -0.443013
# agePct12t21            PctSameCity85           -0.442732
# PctSameCity85          agePct12t21             -0.442732
# medFamInc              rapesPerPop             -0.440112
# rapesPerPop            medFamInc               -0.440112
# pctWSocSec             householdsize           -0.438959
# householdsize          pctWSocSec              -0.438959
#  medIncome             rapesPerPop             -0.438677
# rapesPerPop             medIncome              -0.438677
# pctWRetire             PctEmploy               -0.438006
# PctEmploy              pctWRetire              -0.438006
# PctSpeakEnglOnly       PersPerOwnOccHous       -0.437518
# PersPerOwnOccHous      PctSpeakEnglOnly        -0.437518
# HispPerCap             PctHousNoPhone          -0.437295
# PctHousNoPhone         HispPerCap              -0.437295
# PctOccupManu           RentQrange              -0.437279
# RentQrange             PctOccupManu            -0.437279
# PctHousOwnOcc          PctHousNoPhone          -0.437173
# PctHousNoPhone         PctHousOwnOcc           -0.437173
# RentHighQ              PctLess9thGrade         -0.437106
# PctLess9thGrade        RentHighQ               -0.437106
# larcPerPop             medFamInc               -0.436034
# medFamInc              larcPerPop              -0.436034
# PctSameHouse85         PctImmigRecent          -0.434886
# PctImmigRecent         PctSameHouse85          -0.434886
# PctRecImmig10          racePctWhite            -0.434150
# racePctWhite           PctRecImmig10           -0.434150
# PctOccupMgmtProf       FemalePctDiv            -0.434036
# FemalePctDiv           PctOccupMgmtProf        -0.434036
# pctWWage               PctLess9thGrade         -0.433525
# PctLess9thGrade        pctWWage                -0.433525
# PctBSorMore            FemalePctDiv            -0.433441
# FemalePctDiv           PctBSorMore             -0.433441
# HispPerCap             PctNotHSGrad            -0.432923
# PctNotHSGrad           HispPerCap              -0.432923
# rapesPerPop            PctPersOwnOccup         -0.432910
# PctPersOwnOccup        rapesPerPop             -0.432910
# householdsize          PctSpeakEnglOnly        -0.431761
# PctSpeakEnglOnly       householdsize           -0.431761
# racePctWhite           TotalPctDiv             -0.430432
# TotalPctDiv            racePctWhite            -0.430432
# assaultPerPop          PctPersOwnOccup         -0.428173
# PctPersOwnOccup        assaultPerPop           -0.428173
# PctPopUnderPov         MedNumBR                -0.427880
# MedNumBR               PctPopUnderPov          -0.427880
# PctHousLess3BR         pctWWage                -0.427283
# pctWWage               PctHousLess3BR          -0.427283
# RentLowQ               PctBornSameState        -0.427239
# PctBornSameState       RentLowQ                -0.427239
# PopDens                PctHousOwnOcc           -0.427020
# PctHousOwnOcc          PopDens                 -0.427020
# RentHighQ              MalePctDivorce          -0.426790
# MalePctDivorce         RentHighQ               -0.426790
# MedOwnCostPctInc       PctSpeakEnglOnly        -0.425883
# PctSpeakEnglOnly       MedOwnCostPctInc        -0.425883
# PctLargHouseOccup      pctWInvInc              -0.425611
# pctWInvInc             PctLargHouseOccup       -0.425611
# PctImmigRecent         PctPersOwnOccup         -0.424624
# PctPersOwnOccup        PctImmigRecent          -0.424624
# racePctWhite           PctNotSpeakEnglWell     -0.423911
# PctNotSpeakEnglWell    racePctWhite            -0.423911
# PctHousOwnOcc          PctImmigRecent          -0.423346
# PctImmigRecent         PctHousOwnOcc           -0.423346
# PctLess9thGrade        PctPersOwnOccup         -0.423299
# PctPersOwnOccup        PctLess9thGrade         -0.423299
# PctRecImmig8           racePctWhite            -0.423297
# racePctWhite           PctRecImmig8            -0.423297
# PctEmploy              MedRentPctHousInc       -0.421370
# MedRentPctHousInc      PctEmploy               -0.421370
# larcPerPop             PctPersOwnOccup         -0.420839
# PctPersOwnOccup        larcPerPop              -0.420839
# PctSameCity85          PctImmigRec8            -0.420636
# PctImmigRec8           PctSameCity85           -0.420636
# burglPerPop            medFamInc               -0.419862
# medFamInc              burglPerPop             -0.419862
# pctWSocSec             RentLowQ                -0.418649
# RentLowQ               pctWSocSec              -0.418649
# burglPerPop             medIncome              -0.418530
#  medIncome             burglPerPop             -0.418530
# MedNumBR               TotalPctDiv             -0.418217
# TotalPctDiv            MedNumBR                -0.418217
# PctHousLess3BR          perCapInc              -0.417189
#  perCapInc             PctHousLess3BR          -0.417189
# MalePctDivorce         householdsize           -0.417075
# householdsize          MalePctDivorce          -0.417075
# PctRecImmig5           PctPersOwnOccup         -0.415903
# PctPersOwnOccup        PctRecImmig5            -0.415903
#                        PopDens                 -0.415875
# PopDens                PctPersOwnOccup         -0.415875
# racePctAsian           PctSpeakEnglOnly        -0.415632
# PctSpeakEnglOnly       racePctAsian            -0.415632
#                        PctNotHSGrad            -0.415360
# PctNotHSGrad           PctSpeakEnglOnly        -0.415360
# PctWOFullPlumb         PctKids2Par             -0.415145
# PctKids2Par            PctWOFullPlumb          -0.415145
# MalePctDivorce         MedRent                 -0.414772
# MedRent                MalePctDivorce          -0.414772
# TotalPctDiv            RentHighQ               -0.414438
# RentHighQ              TotalPctDiv             -0.414438
# FemalePctDiv           MedNumBR                -0.414328
# MedNumBR               FemalePctDiv            -0.414328
# PctHousOwnOcc          burglPerPop             -0.414073
# burglPerPop            PctHousOwnOcc           -0.414073
# PctRecentImmig         PctPersOwnOccup         -0.414040
# PctPersOwnOccup        PctRecentImmig          -0.414040
# RentHighQ              PctBornSameState        -0.413209
# PctBornSameState       RentHighQ               -0.413209
# PctFam2Par             arsonsPerPop            -0.412271
# arsonsPerPop           PctFam2Par              -0.412271
# pctWInvInc              racePctHisp            -0.412157
#  racePctHisp           pctWInvInc              -0.412157
#  perCapInc             MalePctDivorce          -0.411906
# MalePctDivorce          perCapInc              -0.411906
# ViolentCrimesPerPop    medFamInc               -0.411764
# medFamInc              ViolentCrimesPerPop     -0.411764
# assaultPerPop          medFamInc               -0.411706
# medFamInc              assaultPerPop           -0.411706
# TotalPctDiv             perCapInc              -0.411406
#  perCapInc             TotalPctDiv             -0.411406
# PctSameCity85          PctImmigRec5            -0.411338
# PctImmigRec5           PctSameCity85           -0.411338
# MalePctDivorce         MedNumBR                -0.411303
# MedNumBR               MalePctDivorce          -0.411303
# PctKids2Par            MedRentPctHousInc       -0.410950
# MedRentPctHousInc      PctKids2Par             -0.410950
# arsonsPerPop           PctKids2Par             -0.410325
# PctKids2Par            arsonsPerPop            -0.410325
# HispPerCap              pctWPubAsst            -0.409072
#  pctWPubAsst           HispPerCap              -0.409072
# PersPerOwnOccHous      TotalPctDiv             -0.408977
# TotalPctDiv            PersPerOwnOccHous       -0.408977
# pctWRetire             PctImmigRec10           -0.408658
# PctImmigRec10          pctWRetire              -0.408658
# racePctWhite            racePctHisp            -0.408489
#  racePctHisp           racePctWhite            -0.408489
# PctBornSameState       RentMedian              -0.408025
# RentMedian             PctBornSameState        -0.408025
#                        MalePctDivorce          -0.407599
# MalePctDivorce         RentMedian              -0.407599
# pctWSocSec              medIncome              -0.407378
#  medIncome             pctWSocSec              -0.407378
# PctRecImmig5           racePctWhite            -0.407367
# racePctWhite           PctRecImmig5            -0.407367
# PctUnemployed          OwnOccHiQuart           -0.406674
# OwnOccHiQuart          PctUnemployed           -0.406674
# TotalPctDiv            MedRent                 -0.404893
# MedRent                TotalPctDiv             -0.404893
# MalePctNevMarr         MedNumBR                -0.404158
# MedNumBR               MalePctNevMarr          -0.404158
# PctTeen2Par            MalePctNevMarr          -0.404138
# MalePctNevMarr         PctTeen2Par             -0.404138
# OwnOccLowQuart         PctUnemployed           -0.403632
# PctUnemployed          OwnOccLowQuart          -0.403632
# PctPersOwnOccup        PctRecImmig8            -0.402825
# PctRecImmig8           PctPersOwnOccup         -0.402825
# autoTheftPerPop        PctPersOwnOccup         -0.402611
# PctPersOwnOccup        autoTheftPerPop         -0.402611
# HispPerCap             PctUnemployed           -0.402593
# PctUnemployed          HispPerCap              -0.402593
# PctPersOwnOccup        murdPerPop              -0.402177
# murdPerPop             PctPersOwnOccup         -0.402177
# PctFam2Par             MalePctNevMarr          -0.401652
# MalePctNevMarr         PctFam2Par              -0.401652
# OwnOccMedVal           PctUnemployed           -0.401191
# PctUnemployed          OwnOccMedVal            -0.401191
# pctWSocSec             PersPerFam              -0.400931
# PersPerFam             pctWSocSec              -0.400931
# MedRentPctHousInc      PctFam2Par              -0.400910
# PctFam2Par             MedRentPctHousInc       -0.400910
# rapesPerPop            PctHousOwnOcc           -0.400874
# PctHousOwnOcc          rapesPerPop             -0.400874
# PctSameCity85          PctImmigRec10           -0.400390
# PctImmigRec10          PctSameCity85           -0.400390
# PctVacMore6Mos         RentLowQ                -0.400298
# RentLowQ               PctVacMore6Mos          -0.400298
# RentQrange             PctHousNoPhone          -0.399797
# PctHousNoPhone         RentQrange              -0.399797
# OwnOccHiQuart          PctBornSameState        -0.399751
# PctBornSameState       OwnOccHiQuart           -0.399751
# MedNumBR               nonViolPerPop           -0.399168
# nonViolPerPop          MedNumBR                -0.399168
#  medIncome             assaultPerPop           -0.398690
# assaultPerPop           medIncome              -0.398690
# ...
#                        HousVacant               0.934165
# HousVacant             larcenies                0.934165
#  agePct65up            pctWSocSec               0.934703
# pctWSocSec              agePct65up              0.934703
# agePct16t24            agePct12t21              0.934932
# agePct12t21            agePct16t24              0.934932
# HousVacant             burglaries               0.935558
# burglaries             HousVacant               0.935558
#  perCapInc             medFamInc                0.935583
# medFamInc               perCapInc               0.935583
# robberies              NumInShelters            0.935589
# NumInShelters          robberies                0.935589
# NumImmig               robberies                0.936400
# robberies              NumImmig                 0.936400
# numbUrban              assaults                 0.937910
# assaults               numbUrban                0.937910
# PctImmigRec8           PctImmigRec5             0.939305
# PctImmigRec5           PctImmigRec8             0.939305
# population             assaults                 0.939446
# assaults               population               0.939446
# PctFam2Par             PctYoungKids2Par         0.939664
# PctYoungKids2Par       PctFam2Par               0.939664
# burglaries             assaults                 0.939751
# assaults               burglaries               0.939751
# larcPerPop             nonViolPerPop            0.940969
# nonViolPerPop          larcPerPop               0.940969
# autoTheft              assaults                 0.941176
# assaults               autoTheft                0.941176
#                        NumUnderPov              0.941404
# NumUnderPov            assaults                 0.941404
# NumKidsBornNeverMar    assaults                 0.942646
# assaults               NumKidsBornNeverMar      0.942646
# PctImmigRec10          PctImmigRec8             0.943147
# PctImmigRec8           PctImmigRec10            0.943147
# NumKidsBornNeverMar    burglaries               0.944042
# burglaries             NumKidsBornNeverMar      0.944042
# assaults               murders                  0.944612
# murders                assaults                 0.944612
# ViolentCrimesPerPop    assaultPerPop            0.945309
# assaultPerPop          ViolentCrimesPerPop      0.945309
# agePct12t29            agePct16t24              0.946245
# agePct16t24            agePct12t29              0.946245
# PctRecImmig8           PctForeignBorn           0.946429
# PctForeignBorn         PctRecImmig8             0.946429
# larcenies              rapes                    0.946701
# rapes                  larcenies                0.946701
# MedRent                RentLowQ                 0.947016
# RentLowQ               MedRent                  0.947016
# NumInShelters          NumStreet                0.947359
# NumStreet              NumInShelters            0.947359
# PctBSorMore            PctOccupMgmtProf         0.949868
# PctOccupMgmtProf       PctBSorMore              0.949868
# autoTheft              larcenies                0.950751
# larcenies              autoTheft                0.950751
# robberies              numbUrban                0.952473
# numbUrban              robberies                0.952473
# population             robberies                0.954619
# robberies              population               0.954619
# rapes                  burglaries               0.954721
# burglaries             rapes                    0.954721
# autoTheft              robberies                0.955979
# robberies              autoTheft                0.955979
# burglaries             murders                  0.956120
# murders                burglaries               0.956120
# PctRecImmig10          PctForeignBorn           0.956653
# PctForeignBorn         PctRecImmig10            0.956653
# murders                numbUrban                0.957484
# numbUrban              murders                  0.957484
# murders                robberies                0.957838
# robberies              murders                  0.957838
# larcenies              NumUnderPov              0.959065
# NumUnderPov            larcenies                0.959065
# murders                population               0.959294
# population             murders                  0.959294
# robberies              NumUnderPov              0.959859
# NumUnderPov            robberies                0.959859
# robberies              assaults                 0.961519
# assaults               robberies                0.961519
# numbUrban              NumKidsBornNeverMar      0.961991
# NumKidsBornNeverMar    numbUrban                0.961991
# RentMedian             RentLowQ                 0.962723
# RentLowQ               RentMedian               0.962723
# OwnOccHiQuart          OwnOccLowQuart           0.963488
# OwnOccLowQuart         OwnOccHiQuart            0.963488
# NumKidsBornNeverMar    population               0.963838
# population             NumKidsBornNeverMar      0.963838
# larcenies              numbUrban                0.965515
# numbUrban              larcenies                0.965515
# PctRecImmig10          PctRecentImmig           0.965885
# PctRecentImmig         PctRecImmig10            0.965885
# autoTheft              NumKidsBornNeverMar      0.965960
# NumKidsBornNeverMar    autoTheft                0.965960
# larcenies              population               0.965977
# population             larcenies                0.965977
# burglaries             numbUrban                0.969934
# numbUrban              burglaries               0.969934
# burglaries             population               0.970524
# population             burglaries               0.970524
# NumUnderPov            burglaries               0.970671
# burglaries             NumUnderPov              0.970671
# murders                autoTheft                0.970705
# autoTheft              murders                  0.970705
#                        burglaries               0.971127
# burglaries             autoTheft                0.971127
# robberies              NumKidsBornNeverMar      0.975088
# NumKidsBornNeverMar    robberies                0.975088
# MalePctDivorce         TotalPctDiv              0.975785
# TotalPctDiv            MalePctDivorce           0.975785
# NumUnderPov            murders                  0.976128
# murders                NumUnderPov              0.976128
# MedRent                RentHighQ                0.976395
# RentHighQ              MedRent                  0.976395
# whitePerCap             perCapInc               0.976993
#  perCapInc             whitePerCap              0.976993
# murders                NumKidsBornNeverMar      0.978138
# NumKidsBornNeverMar    murders                  0.978138
# PctRecentImmig         PctRecImmig8             0.978587
# PctRecImmig8           PctRecentImmig           0.978587
# medFamInc               medIncome               0.979392
#  medIncome             medFamInc                0.979392
# autoTheft              numbUrban                0.979450
# numbUrban              autoTheft                0.979450
# RentHighQ              RentMedian               0.979471
# RentMedian             RentHighQ                0.979471
# population             autoTheft                0.980709
# autoTheft              population               0.980709
# PctHousOwnOcc          PctPersOwnOccup          0.982166
# PctPersOwnOccup        PctHousOwnOcc            0.982166
# NumUnderPov            NumKidsBornNeverMar      0.982306
# NumKidsBornNeverMar    NumUnderPov              0.982306
# autoTheft              NumUnderPov              0.983844
# NumUnderPov            autoTheft                0.983844
# FemalePctDiv           TotalPctDiv              0.983879
# TotalPctDiv            FemalePctDiv             0.983879
# burglaries             larcenies                0.984092
# larcenies              burglaries               0.984092
# numbUrban              NumUnderPov              0.984119
# NumUnderPov            numbUrban                0.984119
# OwnOccMedVal           OwnOccHiQuart            0.984659
# OwnOccHiQuart          OwnOccMedVal             0.984659
# PctRecImmig5           PctRecImmig10            0.984929
# PctRecImmig10          PctRecImmig5             0.984929
# PctLargHouseOccup      PctLargHouseFam          0.985382
# PctLargHouseFam        PctLargHouseOccup        0.985382
# PctKids2Par            PctFam2Par               0.985596
# PctFam2Par             PctKids2Par              0.985596
# population             NumUnderPov              0.986054
# NumUnderPov            population               0.986054
# RentMedian             MedRent                  0.987347
# MedRent                RentMedian               0.987347
# PctRecImmig5           PctRecentImmig           0.989896
# PctRecentImmig         PctRecImmig5             0.989896
# OwnOccLowQuart         OwnOccMedVal             0.991415
# OwnOccMedVal           OwnOccLowQuart           0.991415
# PctRecImmig5           PctRecImmig8             0.993770
# PctRecImmig8           PctRecImmig5             0.993770
# PctRecImmig10          PctRecImmig8             0.995133
# PctRecImmig8           PctRecImmig10            0.995133
# numbUrban              population               0.999052
# population             numbUrban                0.999052
#                        population               1.000000
# arsonsPerPop           arsonsPerPop             1.000000
# PctBSorMore            PctBSorMore              1.000000
# PctUnemployed          PctUnemployed            1.000000
# PctEmploy              PctEmploy                1.000000
# PctEmplManu            PctEmplManu              1.000000
# PctEmplProfServ        PctEmplProfServ          1.000000
# PctOccupManu           PctOccupManu             1.000000
# PctOccupMgmtProf       PctOccupMgmtProf         1.000000
# MalePctDivorce         MalePctDivorce           1.000000
# MalePctNevMarr         MalePctNevMarr           1.000000
# FemalePctDiv           FemalePctDiv             1.000000
# TotalPctDiv            TotalPctDiv              1.000000
# PersPerFam             PersPerFam               1.000000
# PctNotHSGrad           PctNotHSGrad             1.000000
# PctFam2Par             PctFam2Par               1.000000
# PctYoungKids2Par       PctYoungKids2Par         1.000000
# PctTeen2Par            PctTeen2Par              1.000000
# PctWorkMomYoungKids    PctWorkMomYoungKids      1.000000
# PctWorkMom             PctWorkMom               1.000000
# NumKidsBornNeverMar    NumKidsBornNeverMar      1.000000
# PctKidsBornNeverMar    PctKidsBornNeverMar      1.000000
# NumImmig               NumImmig                 1.000000
# PctImmigRecent         PctImmigRecent           1.000000
# PctImmigRec5           PctImmigRec5             1.000000
# PctImmigRec8           PctImmigRec8             1.000000
# PctImmigRec10          PctImmigRec10            1.000000
# PctRecentImmig         PctRecentImmig           1.000000
# PctKids2Par            PctKids2Par              1.000000
# PctRecImmig5           PctRecImmig5             1.000000
# PctLess9thGrade        PctLess9thGrade          1.000000
# NumUnderPov            NumUnderPov              1.000000
# householdsize          householdsize            1.000000
# racepctblack           racepctblack             1.000000
# racePctWhite           racePctWhite             1.000000
# racePctAsian           racePctAsian             1.000000
#  racePctHisp            racePctHisp             1.000000
# agePct12t21            agePct12t21              1.000000
# agePct12t29            agePct12t29              1.000000
# agePct16t24            agePct16t24              1.000000
#  agePct65up             agePct65up              1.000000
# numbUrban              numbUrban                1.000000
#  pctUrban               pctUrban                1.000000
#  medIncome              medIncome               1.000000
# PctPopUnderPov         PctPopUnderPov           1.000000
# pctWWage               pctWWage                 1.000000
# pctWInvInc             pctWInvInc               1.000000
# pctWSocSec             pctWSocSec               1.000000
#  pctWPubAsst            pctWPubAsst             1.000000
# pctWRetire             pctWRetire               1.000000
# medFamInc              medFamInc                1.000000
#  perCapInc              perCapInc               1.000000
# whitePerCap            whitePerCap              1.000000
# blackPerCap            blackPerCap              1.000000
# indianPerCap           indianPerCap             1.000000
# AsianPerCap            AsianPerCap              1.000000
# OtherPerCap            OtherPerCap              1.000000
# HispPerCap             HispPerCap               1.000000
# pctWFarmSelf           pctWFarmSelf             1.000000
# ViolentCrimesPerPop    ViolentCrimesPerPop      1.000000
# PctRecImmig8           PctRecImmig8             1.000000
# PctSpeakEnglOnly       PctSpeakEnglOnly         1.000000
# NumInShelters          NumInShelters            1.000000
# NumStreet              NumStreet                1.000000
# PctForeignBorn         PctForeignBorn           1.000000
# PctBornSameState       PctBornSameState         1.000000
# PctSameHouse85         PctSameHouse85           1.000000
# PctSameCity85          PctSameCity85            1.000000
# PctSameState85         PctSameState85           1.000000
# LandArea               LandArea                 1.000000
# PopDens                PopDens                  1.000000
# PctUsePubTrans         PctUsePubTrans           1.000000
# LemasPctOfficDrugUn    LemasPctOfficDrugUn      1.000000
# murders                murders                  1.000000
# MedOwnCostPctIncNoMtg  MedOwnCostPctIncNoMtg    1.000000
# murdPerPop             murdPerPop               1.000000
# rapesPerPop            rapesPerPop              1.000000
# robberies              robberies                1.000000
# robbbPerPop            robbbPerPop              1.000000
# assaults               assaults                 1.000000
# assaultPerPop          assaultPerPop            1.000000
# burglaries             burglaries               1.000000
# burglPerPop            burglPerPop              1.000000
# larcenies              larcenies                1.000000
# larcPerPop             larcPerPop               1.000000
# autoTheft              autoTheft                1.000000
# autoTheftPerPop        autoTheftPerPop          1.000000
# arsons                 arsons                   1.000000
# rapes                  rapes                    1.000000
# PctRecImmig10          PctRecImmig10            1.000000
# MedOwnCostPctInc       MedOwnCostPctInc         1.000000
# MedRent                MedRent                  1.000000
# PctNotSpeakEnglWell    PctNotSpeakEnglWell      1.000000
# PctLargHouseFam        PctLargHouseFam          1.000000
# PctLargHouseOccup      PctLargHouseOccup        1.000000
# PersPerOccupHous       PersPerOccupHous         1.000000
# PersPerOwnOccHous      PersPerOwnOccHous        1.000000
# PersPerRentOccHous     PersPerRentOccHous       1.000000
# PctPersOwnOccup        PctPersOwnOccup          1.000000
# PctPersDenseHous       PctPersDenseHous         1.000000
# PctHousLess3BR         PctHousLess3BR           1.000000
# MedNumBR               MedNumBR                 1.000000
# HousVacant             HousVacant               1.000000
# PctHousOccup           PctHousOccup             1.000000
# MedRentPctHousInc      MedRentPctHousInc        1.000000
# PctHousOwnOcc          PctHousOwnOcc            1.000000
# PctVacMore6Mos         PctVacMore6Mos           1.000000
# MedYrHousBuilt         MedYrHousBuilt           1.000000
# PctHousNoPhone         PctHousNoPhone           1.000000
# PctWOFullPlumb         PctWOFullPlumb           1.000000
# OwnOccLowQuart         OwnOccLowQuart           1.000000
# OwnOccMedVal           OwnOccMedVal             1.000000
# OwnOccHiQuart          OwnOccHiQuart            1.000000
# OwnOccQrange           OwnOccQrange             1.000000
# RentLowQ               RentLowQ                 1.000000
# RentMedian             RentMedian               1.000000
# RentHighQ              RentHighQ                1.000000
# RentQrange             RentQrange               1.000000
# PctVacantBoarded       PctVacantBoarded         1.000000
# nonViolPerPop          nonViolPerPop            1.000000
# dtype: float64

# %% [markdown]
# Now we will create a dataset for each target variable. This will allow us to see which columns are most correlated when dealing with the specific target variable.

# %% [markdown]
# MURDER CATEGORY:

# %%
#Create dataset for the specific crime target variable

murders_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
murders_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    murders  murdPerPop
# 0        0         0.0
# 1        0         0.0
# 2        3         8.3
# 3        0         0.0
# 4        0         0.0

# %%
#murd_corr = murders_data.corr(method='spearman')

#Create a correlation matrix for the dataframe category
murd_corr = murders_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
murd_tri = murd_corr.where(np.triu(np.ones(murd_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns named 'murd_drop'
murd_drop = [column for column in murd_tri.columns if any(murd_tri[column] > 0.8)]

#drop the murd_drop columns from the dataframe
murders = murders_data.drop(murders_data[murd_drop], axis=1)

murders.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    murdPerPop
# 0         0.0
# 1         0.0
# 2         8.3
# 3         0.0
# 4         0.0

# %%
#FEATURE SELECTION for exploration

#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#import seaborn as sns
#import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %% [markdown]
# RAPE CATEGORY:

# %%
rapes_data = crimedata_new.drop(['murders', 'murdPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
rapes_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    rapes  rapesPerPop
# 0    0.0         0.00
# 1    1.0         4.25
# 2    6.0        16.60
# 3   10.0        57.86
# 4    NaN          NaN

# %%
#Create a correlation matrix for the dataframe category
rapes_corr = rapes_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
rapes_tri = rapes_corr.where(np.triu(np.ones(rapes_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns named 'rapes_drop'
rapes_drop = [column for column in rapes_tri.columns if any(rapes_tri[column] > 0.8)]

#drop the rapes_drop columns from the dataframe
rapes = rapes_data.drop(rapes_data[rapes_drop], axis=1)

rapes.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    rapesPerPop
# 0         0.00
# 1         4.25
# 2        16.60
# 3        57.86
# 4          NaN

# %% [markdown]
# ROBBERY CATEGORY:

# %%
robberies_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'murders', 'murdPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
robberies_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    robberies  robbbPerPop
# 0        1.0         8.20
# 1        5.0        21.26
# 2       56.0       154.95
# 3       10.0        57.86
# 4        4.0        32.04

# %%
#Create a correlation matrix for the dataframe category
robb_corr = robberies_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
robb_tri = robb_corr.where(np.triu(np.ones(robb_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
robb_drop = [column for column in robb_tri.columns if any(robb_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
robberies = robberies_data.drop(robberies_data[robb_drop], axis=1)

robberies.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    robbbPerPop
# 0         8.20
# 1        21.26
# 2       154.95
# 3        57.86
# 4        32.04

# %% [markdown]
# ASSAULT CATEGORY:

# %%
assaults_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'murders', 'murdPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
assaults_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    assaults  assaultPerPop
# 0       4.0          32.81
# 1      24.0         102.05
# 2      14.0          38.74
# 3      33.0         190.93
# 4      14.0         112.14

# %%
#Create a correlation matrix for the dataframe category
assault_corr = assaults_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
assault_tri = assault_corr.where(np.triu(np.ones(assault_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
assault_drop = [column for column in assault_tri.columns if any(assault_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
assaults = assaults_data.drop(assaults_data[assault_drop], axis=1)

assaults.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    assaultPerPop
# 0          32.81
# 1         102.05
# 2          38.74
# 3         190.93
# 4         112.14

# %% [markdown]
# BURGLARIES CATEGORY:

# %%
burglaries_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'murders', 'murdPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
burglaries_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    burglaries  burglPerPop
# 0        14.0       114.85
# 1        57.0       242.37
# 2       274.0       758.14
# 3       225.0      1301.78
# 4        91.0       728.93

# %%
#Create a correlation matrix for the dataframe category
burg_corr = burglaries_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
burg_tri = burg_corr.where(np.triu(np.ones(burg_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
burg_drop = [column for column in burg_tri.columns if any(burg_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
burglaries = burglaries_data.drop(burglaries_data[burg_drop], axis=1)

burglaries.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    burglPerPop
# 0       114.85
# 1       242.37
# 2       758.14
# 3      1301.78
# 4       728.93

# %% [markdown]
# LARCENIES CATEGORY:

# %%
larcenies_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'murders', 'murdPerPop', 'autoTheft', 'autoTheftPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
larcenies_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    larcenies  larcPerPop
# 0      138.0     1132.08
# 1      376.0     1598.78
# 2     1797.0     4972.19
# 3      716.0     4142.56
# 4     1060.0     8490.87

# %%
#Create a correlation matrix for the dataframe category
larc_corr = larcenies_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
larc_tri = larc_corr.where(np.triu(np.ones(larc_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
larc_drop = [column for column in larc_tri.columns if any(larc_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
larcenies = larcenies_data.drop(larcenies_data[larc_drop], axis=1)

larcenies.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    larcPerPop
# 0     1132.08
# 1     1598.78
# 2     4972.19
# 3     4142.56
# 4     8490.87

# %% [markdown]
# AUTOTHEFT CATEGORY:

# %%
autotheft_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'murders', 'murdPerPop', 'arsons', 'arsonsPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
autotheft_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    autoTheft  autoTheftPerPop
# 0       16.0           131.26
# 1       26.0           110.55
# 2      136.0           376.30
# 3       47.0           271.93
# 4       91.0           728.93

# %%
#Create a correlation matrix for the dataframe category
auto_corr = autotheft_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
auto_tri = auto_corr.where(np.triu(np.ones(auto_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
auto_drop = [column for column in auto_tri.columns if any(auto_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
autothefts = autotheft_data.drop(autotheft_data[auto_drop], axis=1)

autothefts.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    autoTheftPerPop
# 0           131.26
# 1           110.55
# 2           376.30
# 3           271.93
# 4           728.93

# %% [markdown]
# ARSONS CATEGORY:

# %%
arsons_data = crimedata_new.drop(['rapes', 'rapesPerPop', 'robberies', 'robbbPerPop', 'assaults', 'assaultPerPop', 'burglaries', 'burglPerPop', 'larcenies', 'larcPerPop', 'autoTheft', 'autoTheftPerPop', 'murders', 'murdPerPop', 'ViolentCrimesPerPop', 'nonViolPerPop'], axis=1)
arsons_data.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctWhite  racePctAsian   racePctHisp  agePct12t21  agePct12t29  \
# 0         91.78          6.50          1.88        12.47        21.44
# 1         95.57          3.44          0.85        11.01        21.30
# 2         94.33          3.43          2.35        11.36        25.88
# 3         97.35          0.50          0.70        12.55        25.20
# 4         89.16          1.17          0.52        24.46        40.53
#
#    agePct16t24   agePct65up  numbUrban   pctUrban   medIncome  pctWWage  \
# 0        10.93        11.33      11980      100.0       75122     89.24
# 1        10.48        17.18      23123      100.0       47917     78.99
# 2        11.01        10.28      29344      100.0       35669     82.00
# 3        12.19        17.57          0        0.0       20580     68.15
# 4        28.69        12.65          0        0.0       17390     69.33
#
#    pctWFarmSelf  pctWInvInc  pctWSocSec   pctWPubAsst  pctWRetire  medFamInc  \
# 0          1.55       70.20       23.62          1.03       18.39      79584
# 1          1.11       64.11       35.50          2.75       22.85      55323
# 2          1.15       55.73       22.25          2.94       14.56      42112
# 3          0.24       38.95       39.48         11.71       18.33      26501
# 4          0.55       42.82       32.16         11.21       14.43      24018
#
#     perCapInc  whitePerCap  blackPerCap  indianPerCap  AsianPerCap  \
# 0       29711        30233        13600          5725        27101
# 1       20148        20191        18137             0        20074
# 2       16946        17103        16644         21606        15528
# 3       10810        10909         9984          4941         3541
# 4        8483         9009          887          4425         3352
#
#    OtherPerCap  HispPerCap  NumUnderPov  PctPopUnderPov  PctLess9thGrade  \
# 0       5115.0       22838          227            1.96             5.81
# 1       5250.0       12222          885            3.98             5.61
# 2       5954.0        8405         1389            4.75             2.80
# 3       2451.0        4391         2831           17.23            11.05
# 4       3000.0        1328         2855           29.99            12.15
#
#    PctNotHSGrad  PctBSorMore  PctUnemployed  PctEmploy  PctEmplManu  \
# 0          9.90        48.18           2.70      64.55        14.65
# 1         13.72        29.89           2.43      61.96        12.26
# 2          9.09        30.13           4.01      69.80        15.95
# 3         33.68        10.81           9.86      54.74        31.22
# 4         23.06        25.28           9.08      52.44         6.89
#
#    PctEmplProfServ  PctOccupManu  PctOccupMgmtProf  MalePctDivorce  \
# 0            28.82          5.49             50.73            3.67
# 1            29.28          6.39             37.64            4.23
# 2            21.52          8.79             32.48           10.10
# 3            27.43         26.76             22.71           10.98
# 4            36.54         10.94             27.80            7.51
#
#    MalePctNevMarr  FemalePctDiv  TotalPctDiv  PersPerFam  PctFam2Par  \
# 0           26.38          5.22         4.47        3.22       91.43
# 1           27.99          6.45         5.42        3.11       86.91
# 2           25.78         14.76        12.55        2.95       78.54
# 3           28.15         14.47        12.91        2.98       64.02
# 4           50.66         11.64         9.73        2.98       58.59
#
#    PctKids2Par  PctYoungKids2Par  PctTeen2Par  PctWorkMomYoungKids  \
# 0        90.17             95.78        95.81                44.56
# 1        85.33             96.82        86.46                51.14
# 2        78.85             92.37        75.72                66.08
# 3        62.36             65.38        67.43                59.59
# 4        55.20             66.51        79.17                61.22
#
#    PctWorkMom  NumKidsBornNeverMar  PctKidsBornNeverMar  NumImmig  \
# 0       58.88                   31                 0.36      1277
# 1       62.43                   43                 0.24      1920
# 2       74.19                  164                 0.88      1468
# 3       70.27                  561                 3.84       339
# 4       68.94                  402                 4.70       196
#
#    PctImmigRecent  PctImmigRec5  PctImmigRec8  PctImmigRec10  PctRecentImmig  \
# 0            8.69         13.00         20.99          30.93            0.93
# 1            5.21          8.65         13.33          22.50            0.43
# 2           16.42         23.98         32.08          35.63            0.82
# 3           13.86         13.86         15.34          15.34            0.28
# 4           46.94         56.12         67.86          69.90            0.82
#
#    PctRecImmig5  PctRecImmig8  PctRecImmig10  PctSpeakEnglOnly  \
# 0          1.39          2.24           3.30             85.68
# 1          0.72          1.11           1.87             87.79
# 2          1.20          1.61           1.78             93.11
# 3          0.28          0.31           0.31             94.98
# 4          0.98          1.18           1.22             94.64
#
#    PctNotSpeakEnglWell  PctLargHouseFam  PctLargHouseOccup  PersPerOccupHous  \
# 0                 1.37             4.81               4.17              2.99
# 1                 1.81             4.25               3.34              2.70
# 2                 1.14             2.97               2.05              2.42
# 3                 0.56             3.93               2.56              2.37
# 4                 0.39             5.23               3.11              2.35
#
#    PersPerOwnOccHous  PersPerRentOccHous  PctPersOwnOccup  PctPersDenseHous  \
# 0               3.00                2.84            91.46              0.39
# 1               2.83                1.96            89.03              1.01
# 2               2.69                2.06            64.18              2.03
# 3               2.51                2.20            58.18              1.21
# 4               2.55                2.12            58.13              2.94
#
#    PctHousLess3BR  MedNumBR  HousVacant  PctHousOccup  PctHousOwnOcc  \
# 0           11.06         3          64         98.37          91.01
# 1           23.60         3         240         97.15          84.88
# 2           47.46         3         544         95.68          57.79
# 3           45.66         3         669         91.19          54.89
# 4           55.64         2         333         92.45          53.57
#
#    PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  PctHousNoPhone  \
# 0              3.12           37.50            1959            0.00
# 1              0.00           18.33            1958            0.31
# 2              0.92            7.54            1976            1.55
# 3              2.54           57.85            1939            7.00
# 4              3.90           42.64            1958            7.45
#
#    PctWOFullPlumb  OwnOccLowQuart  OwnOccMedVal  OwnOccHiQuart  OwnOccQrange  \
# 0            0.28          215900        262600         326900        111000
# 1            0.14          136300        164200         199900         63600
# 2            0.12           74700         90400         112000         37300
# 3            0.87           36400         49600          66500         30100
# 4            0.82           30600         43200          59500         28900
#
#    RentLowQ  RentMedian  RentHighQ  RentQrange  MedRent  MedRentPctHousInc  \
# 0       685        1001       1001         316     1001               23.8
# 1       467         560        672         205      627               27.6
# 2       370         428        520         150      484               24.1
# 3       195         250        309         114      333               28.7
# 4       202         283        362         160      332               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  NumInShelters  NumStreet  \
# 0              21.1                   14.0             11          0
# 1              20.7                   12.5              0          0
# 2              21.7                   11.6             16          0
# 3              20.6                   14.5              0          0
# 4              23.2                   12.9              2          0
#
#    PctForeignBorn  PctBornSameState  PctSameHouse85  PctSameCity85  \
# 0           10.66             53.72           65.29          78.09
# 1            8.30             77.17           71.27          90.22
# 2            5.00             44.77           36.60          61.26
# 3            2.04             88.71           56.70          90.17
# 4            1.74             73.75           42.22          60.34
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    arsons  arsonsPerPop
# 0     2.0         16.41
# 1     1.0          4.25
# 2    22.0         60.87
# 3     NaN           NaN
# 4     5.0         40.05

# %%
#Create a correlation matrix for the dataframe category
arson_corr = arsons_data.corr(numeric_only=True).abs()

#Select the upper triangle of the matrix, excluding the diagnonal elements
arson_tri = arson_corr.where(np.triu(np.ones(arson_corr.shape),k=1).astype(bool))

#drop the columns with a correlation greater than 0.8 and make a list of those columns
arson_drop = [column for column in arson_tri.columns if any(arson_tri[column] > 0.8)]

#drop the columns in the previous list from the dataframe
arsons = arsons_data.drop(arsons_data[arson_drop], axis=1)

arsons.head()
# Out:
#              communityname state  population  householdsize  racepctblack  \
# 0  BerkeleyHeightstownship    NJ       11980           3.10          1.37
# 1           Marpletownship    PA       23123           2.82          0.80
# 2               Tigardcity    OR       29344           2.43          0.74
# 3         Gloversvillecity    NY       16656           2.40          1.70
# 4              Bemidjicity    MN       11245           2.76          0.53
#
#    racePctAsian   racePctHisp  agePct12t21   agePct65up   pctUrban  \
# 0          6.50          1.88        12.47        11.33      100.0
# 1          3.44          0.85        11.01        17.18      100.0
# 2          3.43          2.35        11.36        10.28      100.0
# 3          0.50          0.70        12.55        17.57        0.0
# 4          1.17          0.52        24.46        12.65        0.0
#
#     medIncome  pctWFarmSelf  pctWInvInc   pctWPubAsst  pctWRetire  \
# 0       75122          1.55       70.20          1.03       18.39
# 1       47917          1.11       64.11          2.75       22.85
# 2       35669          1.15       55.73          2.94       14.56
# 3       20580          0.24       38.95         11.71       18.33
# 4       17390          0.55       42.82         11.21       14.43
#
#    blackPerCap  indianPerCap  AsianPerCap  OtherPerCap  HispPerCap  \
# 0        13600          5725        27101       5115.0       22838
# 1        18137             0        20074       5250.0       12222
# 2        16644         21606        15528       5954.0        8405
# 3         9984          4941         3541       2451.0        4391
# 4          887          4425         3352       3000.0        1328
#
#    PctPopUnderPov  PctLess9thGrade  PctBSorMore  PctEmplManu  PctEmplProfServ  \
# 0            1.96             5.81        48.18        14.65            28.82
# 1            3.98             5.61        29.89        12.26            29.28
# 2            4.75             2.80        30.13        15.95            21.52
# 3           17.23            11.05        10.81        31.22            27.43
# 4           29.99            12.15        25.28         6.89            36.54
#
#    PctOccupManu  MalePctDivorce  PctFam2Par  PctWorkMomYoungKids  \
# 0          5.49            3.67       91.43                44.56
# 1          6.39            4.23       86.91                51.14
# 2          8.79           10.10       78.54                66.08
# 3         26.76           10.98       64.02                59.59
# 4         10.94            7.51       58.59                61.22
#
#    PctImmigRecent  PctRecentImmig  PctPersOwnOccup  PctHousLess3BR  MedNumBR  \
# 0            8.69            0.93            91.46           11.06         3
# 1            5.21            0.43            89.03           23.60         3
# 2           16.42            0.82            64.18           47.46         3
# 3           13.86            0.28            58.18           45.66         3
# 4           46.94            0.82            58.13           55.64         2
#
#    PctHousOccup  PctVacantBoarded  PctVacMore6Mos  MedYrHousBuilt  \
# 0         98.37              3.12           37.50            1959
# 1         97.15              0.00           18.33            1958
# 2         95.68              0.92            7.54            1976
# 3         91.19              2.54           57.85            1939
# 4         92.45              3.90           42.64            1958
#
#    PctWOFullPlumb  OwnOccLowQuart  RentQrange  MedRentPctHousInc  \
# 0            0.28          215900         316               23.8
# 1            0.14          136300         205               27.6
# 2            0.12           74700         150               24.1
# 3            0.87           36400         114               28.7
# 4            0.82           30600         160               32.2
#
#    MedOwnCostPctInc  MedOwnCostPctIncNoMtg  PctBornSameState  PctSameHouse85  \
# 0              21.1                   14.0             53.72           65.29
# 1              20.7                   12.5             77.17           71.27
# 2              21.7                   11.6             44.77           36.60
# 3              20.6                   14.5             88.71           56.70
# 4              23.2                   12.9             73.75           42.22
#
#    PctSameState85  LandArea  PopDens  PctUsePubTrans  LemasPctOfficDrugUn  \
# 0           89.14       6.5   1845.9            9.63                  0.0
# 1           96.12      10.6   2186.7            3.84                  0.0
# 2           82.85      10.6   2780.9            4.37                  0.0
# 3           96.24       5.2   3217.7            3.31                  0.0
# 4           89.02      11.5    974.2            0.38                  0.0
#
#    arsonsPerPop
# 0         16.41
# 1          4.25
# 2         60.87
# 3           NaN
# 4         40.05
